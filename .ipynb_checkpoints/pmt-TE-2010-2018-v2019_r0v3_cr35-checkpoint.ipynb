# %%
# Parameters parsed via papermill
cur_station = "MER"
perc_size = 0.97
test_identifier = "MER_0_97_t_t"
test_str = "pmt-TE-2010-2018-v2019_r0v3_cr35"

# %%
# Parameters not parsed via papermill
batch_size = 1000

# %% [markdown]
# Test features:
# bootstrap(per 97 x 15), patience = 150,

# %%
import tensorflow as tf

# %%
def select_available_gpus(num_gpus, memory_limit=7168):
    # Obtener la lista de todas las GPUs disponibles
    gpus = tf.config.list_physical_devices('GPU')
    if not gpus:
        return []
    
    # Seleccionar las primeras 'num_gpus' GPUs
    selected_gpus = gpus[:num_gpus]
    
    # Configurar TensorFlow para usar las GPUs seleccionadas
    try:
        tf.config.experimental.set_visible_devices(selected_gpus, 'GPU')
        for gpu in selected_gpus:
            tf.config.experimental.set_virtual_device_configuration(
                gpu, [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)])
            tf.config.experimental.set_memory_growth(gpu, True)
        return selected_gpus
    except RuntimeError as e:
        print(e)
        return []

try:
    #selected_gpus = select_available_gpus(2)
    #print(f"Se han seleccionado {len(selected_gpus)} GPUs con 7.375 GB de memoria cada una.")
    # Configuración de la estrategia de distribución en GPUs
    strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"])
    print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

except ValueError as e:
    print(e)
# Out:
# 2023-05-04 12:21:08.815546: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 12:21:11.154443: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7375 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1
# 2023-05-04 12:21:11.155167: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 7375 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:03:00.0, compute capability: 6.1
# 2023-05-04 12:21:11.155710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 7375 MB memory:  -> device: 2, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:84:00.0, compute capability: 6.1
# 2023-05-04 12:21:11.156252: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 7375 MB memory:  -> device: 3, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:85:00.0, compute capability: 6.1
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
# Not changed parameters

data_folder = '/data/AirPollutionData/'

grid_size = 4

merged_specific_folder = f'{grid_size*grid_size}' # We may have multiple folders inside merge depending on the cuadrants

_run_name = F'2023_{test_identifier}'  # Name of the model, for training and classification

stations_2020 = ["UIZ","AJU" ,"ATI" ,"CUA" ,"SFE" ,"SAG" ,"CUT" ,"PED" ,"TAH" ,"GAM" ,"IZT" ,"CCA" ,"HGM" ,"LPR" ,
                 "MGH" ,"CAM" ,"FAC" ,"TLA" ,"MER" ,"XAL" ,"LLA" ,"TLI" ,"UAX" ,"BJU" ,"MPA" ,
                 "MON" ,"NEZ" ,"INN" ,"AJM" ,"VIF"]

_debug = False

filter_training_hours = False

start_year = 2010

end_year = 2018

cur_pollutant = 'cont_otres'



all_stations = ["UIZ","AJU" ,"ATI" ,"CUA" ,"SFE" ,"SAG" ,"CUT" ,"PED" ,"TAH" ,"GAM" ,"IZT" ,"CCA" ,"HGM" ,"LPR" ,
                 "MGH" ,"CAM" ,"FAC" ,"TLA" ,"MER" ,"XAL" ,"LLA" ,"TLI" ,"UAX" ,"BJU" ,"MPA" ,
                 "MON" ,"NEZ" ,"INN" ,"AJM" ,"VIF"]

test_year = 2019

# %%
import scrapbook as sb
from os.path import join

import sys

source_path = "/home/olmozavala/Dropbox/MyProjects/EOAS/UNAM/Pollution_Forecast_CDMX/PollutionForecastOZ/"
sys.path.append(join(source_path, 'eoas_pyutils'))
sys.path.append(source_path)

from ai_common.constants.AI_params import NormParams, TrainingParams, ModelParams
import ai_common.training.trainingutils as utilsNN
from ai_common.models.modelSelector import select_1d_model

from viz_utils.eoa_viz import EOAImageVisualizer
from io_utils.io_common import create_folder
from conf.localConstants import constants
from conf.TrainingUserConfiguration import getTrainingParams
from conf.params import LocalTrainingParams

from datetime import date, datetime, timedelta
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import numpy as np
import pandas as pd
from pandas import DataFrame
from sklearn import preprocessing
from os.path import join
import matplotlib.pyplot as plt

#tf.config.experimental.VirtualDeviceConfiguration(memory_limit=12288)

# %%
import tensorflow.keras.metrics as metrics
import tensorflow.keras.losses as losses
from tensorflow.keras.optimizers import *
from ai_common.constants.AI_params import ModelParams, AiModels, TrainingParams, ClassificationParams, VisualizationResultsParams, NormParams

def append_model_params(cur_config):
    model_config = {
        ModelParams.MODEL: AiModels.ML_PERCEPTRON,
        ModelParams.DROPOUT: True,
        ModelParams.BATCH_NORMALIZATION: True,
        #ModelParams.CELLS_PER_HIDDEN_LAYER: [300, 50],
        # ModelParams.CELLS_PER_HIDDEN_LAYER: [300, 300, 300],
        ModelParams.CELLS_PER_HIDDEN_LAYER: [300, 300, 200, 100, 100, 100, 100, 100, 100],
        ModelParams.NUMBER_OF_OUTPUT_CLASSES: 1,
        ModelParams.ACTIVATION_HIDDEN_LAYERS: 'relu',
        ModelParams.ACTIVATION_OUTPUT_LAYERS: None
    }
    model_config[ModelParams.HIDDEN_LAYERS] = len(model_config[ModelParams.CELLS_PER_HIDDEN_LAYER])
    return {**cur_config, **model_config}

def getTrainingParams2():
    cur_config = {
        TrainingParams.input_folder: join(data_folder, constants.merge_output_folder.value, merged_specific_folder),
        TrainingParams.output_folder: F"{join(data_folder, constants.training_output_folder.value,f'{test_str}')}",        
        TrainingParams.validation_percentage: .1,
        TrainingParams.test_percentage: 0, # We will test with a diferent day
        TrainingParams.evaluation_metrics: [metrics.mean_squared_error],  # Metrics to show in tensor flow in the training
        TrainingParams.loss_function: losses.mean_squared_error,  # Loss function to use for the learning
        
        #TrainingParams.evaluation_metrics: [metrics.mean_squared_logarithmic_error], #mean_squared_error],  # Metrics to show in tensor flow in the training
        #TrainingParams.loss_function: losses.mean_squared_logarithmic_error, # PS_test:losses.mean_squared_error,  # Loss function to use for the learning

        # TrainingParams.loss_function: metrics.mean_squared_error,  # Loss function to use for the learning
        TrainingParams.optimizer: Adam(), #learning_rate=0.0005,beta_1=0.99,beta_2=0.999,epsilon=1e-07),#),  # Default values lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None,
        TrainingParams.batch_size: batch_size, #200,
        TrainingParams.epochs: 5000,
        TrainingParams.config_name: _run_name,
        TrainingParams.data_augmentation: False,
        TrainingParams.normalization_type: NormParams.mean_zero,
        LocalTrainingParams.stations: stations_2020,
        LocalTrainingParams.pollutants: ["cont_otres"],
        LocalTrainingParams.forecasted_hours: 24,
        LocalTrainingParams.tot_num_quadrants: 64,  # 8x8
        LocalTrainingParams.num_hours_in_netcdf: 24,
        LocalTrainingParams.years: range(start_year, end_year),
        LocalTrainingParams.debug: _debug,
        LocalTrainingParams.filter_dates: filter_training_hours
    }
    return append_model_params(cur_config)


config = getTrainingParams2()

stations = ['UIZ', 'CUA', 'PED', 'CCA'] #,'AJU', 'FAC', 'MER', 'XAL']#config[LocalTrainingParams.stations]
pollutants = config[LocalTrainingParams.pollutants]

print("config values:\n")
for key, value in config.items():
    print(f"{key} : {value}")

print(f"""

stations: {stations}

pollutants: {pollutants}

start_year: {start_year}

end_year: {end_year}
""")
# Out:
# config values:
#
# TrainingParams.input_folder : /data/AirPollutionData/MergedDataCSV/16
# TrainingParams.output_folder : /data/AirPollutionData/Training/pmt-TE-2010-2018-v2019_r0v3_cr35
# TrainingParams.validation_percentage : 0.1
# TrainingParams.test_percentage : 0
# TrainingParams.evaluation_metrics : [<function mean_squared_error at 0x7f64a92e59d0>]
# TrainingParams.loss_function : <function mean_squared_error at 0x7f64a92e59d0>
# TrainingParams.optimizer : <keras.optimizer_v2.adam.Adam object at 0x7f6499b992b0>
# TrainingParams.batch_size : 1000
# TrainingParams.epochs : 5000
# TrainingParams.config_name : 2023_MER_0_97_t_t
# TrainingParams.data_augmentation : False
# TrainingParams.normalization_type : NormParams.mean_zero
# LocalTrainingParams.stations : ['UIZ', 'AJU', 'ATI', 'CUA', 'SFE', 'SAG', 'CUT', 'PED', 'TAH', 'GAM', 'IZT', 'CCA', 'HGM', 'LPR', 'MGH', 'CAM', 'FAC', 'TLA', 'MER', 'XAL', 'LLA', 'TLI', 'UAX', 'BJU', 'MPA', 'MON', 'NEZ', 'INN', 'AJM', 'VIF']
# LocalTrainingParams.pollutants : ['cont_otres']
# LocalTrainingParams.forecasted_hours : 24
# LocalTrainingParams.tot_num_quadrants : 64
# LocalTrainingParams.num_hours_in_netcdf : 24
# LocalTrainingParams.years : range(2010, 2018)
# LocalTrainingParams.debug : False
# LocalTrainingParams.filter_dates : False
# ModelParams.MODEL : AiModels.ML_PERCEPTRON
# ModelParams.DROPOUT : True
# ModelParams.BATCH_NORMALIZATION : True
# ModelParams.CELLS_PER_HIDDEN_LAYER : [300, 300, 200, 100, 100, 100, 100, 100, 100]
# ModelParams.NUMBER_OF_OUTPUT_CLASSES : 1
# ModelParams.ACTIVATION_HIDDEN_LAYERS : relu
# ModelParams.ACTIVATION_OUTPUT_LAYERS : None
# ModelParams.HIDDEN_LAYERS : 9
#
#
# stations: ['UIZ', 'CUA', 'PED', 'CCA']
#
# pollutants: ['cont_otres']
#
# start_year: 2010
#
# end_year: 2018

# %%
import sys
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from os.path import join
from datetime import date, datetime, timedelta
from sklearn import preprocessing

import scrapbook as sb
from ai_common.constants.AI_params import NormParams, TrainingParams, ModelParams
import ai_common.training.trainingutils as utilsNN
from ai_common.models.modelSelector import select_1d_model
from viz_utils.eoa_viz import EOAImageVisualizer
from io_utils.io_common import create_folder
from conf.localConstants import constants
from conf.TrainingUserConfiguration import getTrainingParams
from conf.params import LocalTrainingParams

# Function definitions

def select_available_gpus(num_gpus, memory_limit=7168):
    # Obtener la lista de todas las GPUs disponibles
    gpus = tf.config.list_physical_devices('GPU')
    if not gpus:
        return []
    
    # Seleccionar las primeras 'num_gpus' GPUs
    selected_gpus = gpus[:num_gpus]
    
    # Configurar TensorFlow para usar las GPUs seleccionadas
    try:
        tf.config.experimental.set_visible_devices(selected_gpus, 'GPU')
        for gpu in selected_gpus:
            tf.config.experimental.set_virtual_device_configuration(
                gpu, [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)])
            tf.config.experimental.set_memory_growth(gpu, True)
        return selected_gpus
    except RuntimeError as e:
        print(e)
        return []
    

def append_model_params(cur_config):
    model_config = {
        ModelParams.MODEL: AiModels.ML_PERCEPTRON,
        ModelParams.DROPOUT: True,
        ModelParams.BATCH_NORMALIZATION: True,
        #ModelParams.CELLS_PER_HIDDEN_LAYER: [300, 50],
        # ModelParams.CELLS_PER_HIDDEN_LAYER: [300, 300, 300],
        ModelParams.CELLS_PER_HIDDEN_LAYER: [300, 300, 200, 100, 100, 100, 100, 100, 100],
        ModelParams.NUMBER_OF_OUTPUT_CLASSES: 1,
        ModelParams.ACTIVATION_HIDDEN_LAYERS: 'relu',
        ModelParams.ACTIVATION_OUTPUT_LAYERS: None
    }
    model_config[ModelParams.HIDDEN_LAYERS] = len(model_config[ModelParams.CELLS_PER_HIDDEN_LAYER])
    return {**cur_config, **model_config}

def getTrainingParams2():
    cur_config = {
        TrainingParams.input_folder: join(data_folder, constants.merge_output_folder.value, merged_specific_folder),
        TrainingParams.output_folder: F"{join(data_folder, constants.training_output_folder.value,f'{test_str}')}",        
        TrainingParams.validation_percentage: .1,
        TrainingParams.test_percentage: 0, # We will test with a diferent day
        TrainingParams.evaluation_metrics: [metrics.mean_squared_error],  # Metrics to show in tensor flow in the training
        TrainingParams.loss_function: losses.mean_squared_error,  # Loss function to use for the learning
        
        #TrainingParams.evaluation_metrics: [metrics.mean_squared_logarithmic_error], #mean_squared_error],  # Metrics to show in tensor flow in the training
        #TrainingParams.loss_function: losses.mean_squared_logarithmic_error, # PS_test:losses.mean_squared_error,  # Loss function to use for the learning

        # TrainingParams.loss_function: metrics.mean_squared_error,  # Loss function to use for the learning
        TrainingParams.optimizer: Adam(), #learning_rate=0.0005,beta_1=0.99,beta_2=0.999,epsilon=1e-07),#),  # Default values lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None,
        TrainingParams.batch_size: batch_size, #200,
        TrainingParams.epochs: 5000,
        TrainingParams.config_name: _run_name,
        TrainingParams.data_augmentation: False,
        TrainingParams.normalization_type: NormParams.mean_zero,
        LocalTrainingParams.stations: stations_2020,
        LocalTrainingParams.pollutants: ["cont_otres"],
        LocalTrainingParams.forecasted_hours: 24,
        LocalTrainingParams.tot_num_quadrants: 64,  # 8x8
        LocalTrainingParams.num_hours_in_netcdf: 24,
        LocalTrainingParams.years: range(start_year, end_year),
        LocalTrainingParams.debug: _debug,
        LocalTrainingParams.filter_dates: filter_training_hours
    }
    return append_model_params(cur_config)

# Variable definitions
data_folder = '/ZION/AirPollutionData/Data/'
grid_size = 4
merged_specific_folder = f'{grid_size*grid_size}'
_run_name = F'2023_{test_identifier}'
stations_2020 = ["UIZ", "AJU", "ATI", "CUA", "SFE", "SAG", "CUT", "PED", "TAH", "GAM", "IZT", "CCA", "HGM", "LPR",
                 "MGH", "CAM", "FAC", "TLA", "MER", "XAL", "LLA", "TLI", "UAX", "BJU", "MPA",
                 "MON", "NEZ", "INN", "AJM", "VIF"]
_debug = False
filter_training_hours = False
start_year = 2010
end_year = 2018
cur_pollutant = 'cont_otres'
all_stations = ["UIZ", "AJU", "ATI", "CUA", "SFE", "SAG", "CUT", "PED", "TAH", "GAM", "IZT", "CCA", "HGM", "LPR",
                "MGH", "CAM", "FAC", "TLA", "MER", "XAL", "LLA", "TLI", "UAX", "BJU", "MPA",
                "MON", "NEZ", "INN", "AJM", "VIF"]
test_year = 2019

# TensorFlow configuration
try:
    strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"])
    print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
except ValueError as e:
    print(e)

# Load configuration and print values
config = getTrainingParams2()
stations = ['UIZ', 'CUA', 'PED', 'CCA']
pollutants = config[LocalTrainingParams.pollutants]


print("config values:\n")
for key, value in config.items():
    print(f"{key} : {value}")

print(f"""

stations: {stations}

pollutants: {pollutants}

start_year: {start_year}

end_year: {end_year}
""")
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2
# config values:
#
# TrainingParams.input_folder : /ZION/AirPollutionData/Data/MergedDataCSV/16
# TrainingParams.output_folder : /ZION/AirPollutionData/Data/Training/pmt-TE-2010-2018-v2019_r0v3_cr35
# TrainingParams.validation_percentage : 0.1
# TrainingParams.test_percentage : 0
# TrainingParams.evaluation_metrics : [<function mean_squared_error at 0x7f576fa14c10>]
# TrainingParams.loss_function : <function mean_squared_error at 0x7f576fa14c10>
# TrainingParams.optimizer : <keras.optimizer_v2.adam.Adam object at 0x7f585985f7f0>
# TrainingParams.batch_size : 1000
# TrainingParams.epochs : 5000
# TrainingParams.config_name : 2023_MER_0_97_t_t
# TrainingParams.data_augmentation : False
# TrainingParams.normalization_type : NormParams.mean_zero
# LocalTrainingParams.stations : ['UIZ', 'AJU', 'ATI', 'CUA', 'SFE', 'SAG', 'CUT', 'PED', 'TAH', 'GAM', 'IZT', 'CCA', 'HGM', 'LPR', 'MGH', 'CAM', 'FAC', 'TLA', 'MER', 'XAL', 'LLA', 'TLI', 'UAX', 'BJU', 'MPA', 'MON', 'NEZ', 'INN', 'AJM', 'VIF']
# LocalTrainingParams.pollutants : ['cont_otres']
# LocalTrainingParams.forecasted_hours : 24
# LocalTrainingParams.tot_num_quadrants : 64
# LocalTrainingParams.num_hours_in_netcdf : 24
# LocalTrainingParams.years : range(2010, 2018)
# LocalTrainingParams.debug : False
# LocalTrainingParams.filter_dates : False
# ModelParams.MODEL : AiModels.ML_PERCEPTRON
# ModelParams.DROPOUT : True
# ModelParams.BATCH_NORMALIZATION : True
# ModelParams.CELLS_PER_HIDDEN_LAYER : [300, 300, 200, 100, 100, 100, 100, 100, 100]
# ModelParams.NUMBER_OF_OUTPUT_CLASSES : 1
# ModelParams.ACTIVATION_HIDDEN_LAYERS : relu
# ModelParams.ACTIVATION_OUTPUT_LAYERS : None
# ModelParams.HIDDEN_LAYERS : 9
#
#
# stations: ['UIZ', 'CUA', 'PED', 'CCA']
#
# pollutants: ['cont_otres']
#
# start_year: 2010
#
# end_year: 2018

# %%
# data = readData(config, cur_pollutant, start_year, end_year)

def readData(config, cur_pollutant, start_year, end_year):
    '''
    Reads all the years for the selected pollutant for all the stations
    :param config:
    :param cur_pollutant:
    :param start_year:
    :param end_year:
    :param all_stations:
    :return:
    '''
    input_folder = config[TrainingParams.input_folder]
    # -------- Reading all the years in a single data frame (all stations)
    for c_year in range(start_year, end_year+1):
        db_file_name = join(input_folder, F"{c_year}_{cur_pollutant}_AllStations.csv") # Just for testing
        print(F"============ Reading data for: {cur_pollutant}: {db_file_name}")
        if c_year == start_year:
            data = pd.read_csv(db_file_name, index_col=0)
        else:
            data = pd.concat([data, pd.read_csv(db_file_name, index_col=0)])

    return data

data = readData(config, cur_pollutant, start_year, end_year)
# Out:
# ============ Reading data for: cont_otres: /ZION/AirPollutionData/Data/MergedDataCSV/16/2010_cont_otres_AllStations.csv
# ============ Reading data for: cont_otres: /ZION/AirPollutionData/Data/MergedDataCSV/16/2011_cont_otres_AllStations.csv
# ============ Reading data for: cont_otres: /ZION/AirPollutionData/Data/MergedDataCSV/16/2012_cont_otres_AllStations.csv
# ============ Reading data for: cont_otres: /ZION/AirPollutionData/Data/MergedDataCSV/16/2013_cont_otres_AllStations.csv
# ============ Reading data for: cont_otres: /ZION/AirPollutionData/Data/MergedDataCSV/16/2014_cont_otres_AllStations.csv
# ============ Reading data for: cont_otres: /ZION/AirPollutionData/Data/MergedDataCSV/16/2015_cont_otres_AllStations.csv
# ============ Reading data for: cont_otres: /ZION/AirPollutionData/Data/MergedDataCSV/16/2016_cont_otres_AllStations.csv
# ============ Reading data for: cont_otres: /ZION/AirPollutionData/Data/MergedDataCSV/16/2017_cont_otres_AllStations.csv
# ============ Reading data for: cont_otres: /ZION/AirPollutionData/Data/MergedDataCSV/16/2018_cont_otres_AllStations.csv

# %%
# Configure the paths
input_folder = config[TrainingParams.input_folder]
output_folder = config[TrainingParams.output_folder]
output_folder = join(output_folder, f"{cur_pollutant}_{cur_station}")

# Set up the training parameters
val_perc = config[TrainingParams.validation_percentage]
test_perc = config[TrainingParams.test_percentage]
eval_metrics = config[TrainingParams.evaluation_metrics]
loss_func = config[TrainingParams.loss_function]
batch_size = config[TrainingParams.batch_size]
epochs = config[TrainingParams.epochs]
model_name_user = config[TrainingParams.config_name]
optimizer = config[TrainingParams.optimizer]
forecasted_hours = config[LocalTrainingParams.forecasted_hours]
norm_type = config[TrainingParams.normalization_type]

# Configure the output folders
split_info_folder = join(output_folder, 'Splits')
parameters_folder = join(output_folder, 'Parameters')
weights_folder = join(output_folder, 'models')
logs_folder = join(output_folder, 'logs')
imgs_folder = join(output_folder, 'imgs')

# Create output folders
create_folder(split_info_folder)
create_folder(parameters_folder)
create_folder(weights_folder)
create_folder(logs_folder)

# Set up the visualizer
viz_obj = EOAImageVisualizer(output_folder=imgs_folder, disp_images=False)

# Remove unused stations and handle missing values
remove_columns = [x for x in all_stations if x.find(cur_station) == -1]
data.loc[:, remove_columns] = data.loc[:, remove_columns].fillna(-200)
data = data.dropna()

# %%
data
# Out:
#                      U10_0_h0  U10_1_h0  U10_2_h0  U10_3_h0  U10_4_h0  \
# fecha
# 2010-01-01 00:00:00      0.95      1.09      1.41      1.47      0.87
# 2010-01-01 01:00:00      1.02      1.81      1.31      1.06      1.44
# 2010-01-01 02:00:00      0.66      1.99      0.94      0.11      2.37
# 2010-01-01 03:00:00      0.19      1.90      0.86     -0.12      2.08
# 2010-01-01 04:00:00     -0.18      1.99      0.79     -0.59      1.53
# ...                       ...       ...       ...       ...       ...
# 2018-12-31 19:00:00      0.68     -0.69     -0.67      0.46     -0.25
# 2018-12-31 20:00:00      0.90     -0.56     -0.48      0.48     -0.14
# 2018-12-31 21:00:00      0.78     -0.83     -0.44      0.42     -0.23
# 2018-12-31 22:00:00      0.85     -0.73     -0.02      0.70     -0.04
# 2018-12-31 23:00:00      0.69     -0.31      0.37      0.66      0.27
#
#                      U10_5_h0  U10_6_h0  U10_7_h0  U10_8_h0  U10_9_h0  ...  \
# fecha                                                                  ...
# 2010-01-01 00:00:00      1.03      1.35      1.40      0.68      0.77  ...
# 2010-01-01 01:00:00      0.89      1.10      1.06      2.29      1.53  ...
# 2010-01-01 02:00:00      2.59      0.12     -0.25      2.84      1.48  ...
# 2010-01-01 03:00:00      2.79      0.25     -0.95      2.52      1.16  ...
# 2010-01-01 04:00:00      2.69     -0.97     -2.18      2.65      1.16  ...
# ...                       ...       ...       ...       ...       ...  ...
# 2018-12-31 19:00:00     -1.31     -0.45      1.05     -1.73     -1.46  ...
# 2018-12-31 20:00:00     -1.32     -0.47      1.05     -1.87     -1.77  ...
# 2018-12-31 21:00:00     -1.56     -0.75      0.66     -2.33     -1.83  ...
# 2018-12-31 22:00:00     -1.36     -0.97      0.77     -1.69     -1.23  ...
# 2018-12-31 23:00:00     -1.13     -1.44      0.51     -1.47     -0.90  ...
#
#                        LLA    TLI    UAX    BJU    MPA   MON    NEZ    INN  \
# fecha
# 2010-01-01 00:00:00 -200.0 -200.0 -200.0 -200.0 -200.0   4.0 -200.0 -200.0
# 2010-01-01 01:00:00 -200.0 -200.0 -200.0 -200.0 -200.0   5.0 -200.0 -200.0
# 2010-01-01 02:00:00 -200.0 -200.0 -200.0 -200.0 -200.0  12.0 -200.0 -200.0
# 2010-01-01 03:00:00 -200.0 -200.0 -200.0 -200.0 -200.0  32.0 -200.0 -200.0
# 2010-01-01 04:00:00 -200.0 -200.0 -200.0 -200.0 -200.0  33.0 -200.0 -200.0
# ...                    ...    ...    ...    ...    ...   ...    ...    ...
# 2018-12-31 19:00:00   19.0   34.0   27.0   37.0   31.0  40.0   26.0   35.0
# 2018-12-31 20:00:00    6.0   28.0   12.0    7.0   35.0  26.0   21.0   25.0
# 2018-12-31 21:00:00   16.0   17.0   16.0    8.0   33.0  16.0    6.0   35.0
# 2018-12-31 22:00:00   19.0    5.0   13.0   10.0   36.0  19.0    3.0   34.0
# 2018-12-31 23:00:00   12.0    6.0    7.0    3.0   36.0  14.0    1.0   30.0
#
#                        AJM    VIF
# fecha
# 2010-01-01 00:00:00 -200.0 -200.0
# 2010-01-01 01:00:00 -200.0 -200.0
# 2010-01-01 02:00:00 -200.0 -200.0
# 2010-01-01 03:00:00 -200.0 -200.0
# 2010-01-01 04:00:00 -200.0 -200.0
# ...                    ...    ...
# 2018-12-31 19:00:00   38.0   26.0
# 2018-12-31 20:00:00   34.0   19.0
# 2018-12-31 21:00:00   21.0   10.0
# 2018-12-31 22:00:00   26.0    6.0
# 2018-12-31 23:00:00   33.0    4.0
#
# [72594 rows x 2724 columns]

# %%
columnas = data.columns
print(len(columnas))
# Out:
# 2724

# %%
# Add the last 23 hours of pollutants to the dataset as hm1 -> minus 1hr, ...
for index, row in data.iterrows():
    dt_row = datetime.strptime(index, constants.datetime_format.value)
    
    for i in range(24):
        dt_target = dt_row - timedelta(hours=i)
        dt_target_str = dt_target.strftime('%Y-%m-%d %H:%M:%S')
        
        temp_val = np.nan
        if dt_target_str in data.index:
            temp_val = data.loc[dt_target_str][f'{cur_station}']
        
        data.loc[f'{index}', f'{cur_station}_hm{i}'] = temp_val

# Move the cur_station column to the end of the DataFrame for normalization
columna = data.pop(f"{cur_station}")
data[f"{cur_station}"] = columna
# Out:
# /tmp/ipykernel_3473445/1668394270.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{cur_station}"] = columna

# %%
data = data.fillna(-200)
data
# Out:
#                      U10_0_h0  U10_1_h0  U10_2_h0  U10_3_h0  U10_4_h0  \
# fecha
# 2010-01-01 00:00:00      0.95      1.09      1.41      1.47      0.87
# 2010-01-01 01:00:00      1.02      1.81      1.31      1.06      1.44
# 2010-01-01 02:00:00      0.66      1.99      0.94      0.11      2.37
# 2010-01-01 03:00:00      0.19      1.90      0.86     -0.12      2.08
# 2010-01-01 04:00:00     -0.18      1.99      0.79     -0.59      1.53
# 2018-12-31 23:00:00       9.0       9.0       9.0       5.0   4.0
#
# [72594 rows x 2748 columns]

# %%
import pandas as pd
import glob
import re

def load_dataframes(input_folder, regex):
    file_names = glob.glob(input_folder + "/*")
    dataframes = {}
    
    for file_name in file_names:
        match = re.search(regex, file_name)
        
        if match:
            key = match.group(1)
            df = pd.read_csv(file_name, index_col=0)
            df = df.loc['2010-01-01':]
            df = df[~df.index.duplicated()]
            
            if key == 'otres_':
                continue
            
            if key in dataframes:
                dataframes[key] = pd.concat([dataframes[key], df], axis=1)
            else:
                dataframes[key] = df
                
    return dataframes

input_folder = "/ZION/AirPollutionData/Data/DataPollutionDB_CSV"
regex = f"cont_(.*?){cur_station}\.csv"

print(f'Buscando con la expresión regular: {regex}')

dataframes = load_dataframes(input_folder, regex)
data_cont = pd.concat(dataframes.values(), axis=1)
data_cont = data_cont[~data_cont.index.duplicated()]
data_cont.fillna(-200)
# Out:
# Buscando con la expresión regular: cont_(.*?)MER\.csv
#                      cont_pmco  cont_pmdoscinco  cont_nox  cont_co  \
# fecha
# 2012-01-01 00:00:00       28.0             62.0      93.0      1.7
# 2012-01-01 01:00:00       47.0            102.0     101.0      1.9
# 2012-01-01 02:00:00       45.0            111.0     102.0      1.9
# 2012-01-01 03:00:00       43.0            113.0     126.0      2.3
# 2012-01-01 04:00:00       37.0            103.0     122.0      2.3
# ...                        ...              ...       ...      ...
# 2012-12-19 11:00:00     -200.0           -200.0    -200.0   -200.0
# 2012-12-23 17:00:00     -200.0           -200.0    -200.0   -200.0
# 2012-12-27 10:00:00     -200.0           -200.0    -200.0   -200.0
# 2012-12-31 02:00:00     -200.0           -200.0    -200.0   -200.0
# 2018-10-27 00:00:00     -200.0           -200.0    -200.0   -200.0
#
#                      cont_nodos  cont_no  cont_sodos  cont_pmdiez
# fecha
# 2012-01-01 00:00:00        45.0     48.0         7.0         90.0
# 2012-01-01 01:00:00        46.0     54.0        10.0        148.0
# 2012-01-01 02:00:00        46.0     56.0         9.0        156.0
# 2012-01-01 03:00:00        44.0     82.0         9.0        156.0
# 2012-01-01 04:00:00        40.0     81.0         8.0        141.0
# ...                         ...      ...         ...          ...
# 2012-12-19 11:00:00      -200.0   -200.0      -200.0         80.0
# 2012-12-23 17:00:00      -200.0   -200.0      -200.0         66.0
# 2012-12-27 10:00:00      -200.0   -200.0      -200.0         60.0
# 2012-12-31 02:00:00      -200.0   -200.0      -200.0          6.0
# 2018-10-27 00:00:00      -200.0   -200.0      -200.0          0.0
#
# [84038 rows x 8 columns]

# %%
# Concatenar columnas de contaminantes
data_cont_cols = data_cont.columns

# Concatenar todas las columnas de data_cont con data
data = pd.concat([data, data_cont[data_cont_cols]], axis=1)

# Eliminar filas con NaN en la columna cur_station
data = data.dropna(subset=[cur_station])

# Rellenar valores faltantes con -200
data.fillna(-200, inplace=True)

# Mover la columna cur_station al final del DataFrame para su normalización
columna = data.pop(f"{cur_station}")
data[f"{cur_station}"] = columna
# Out:
# /tmp/ipykernel_3473445/1775755506.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[
# 2010-01-01 03:00:00        18.0      1.0         2.0         31.0  24.0
# 2010-01-01 04:00:00        15.0      1.0         2.0         33.0  21.0
# ...                         ...      ...         ...          ...   ...
# 2018-12-31 19:00:00        37.0      3.0         3.0         35.0  17.0
# 2018-12-31 20:00:00        46.0      8.0         3.0         54.0   7.0
# 2018-12-31 21:00:00        53.0     43.0         5.0         61.0   3.0
# 2018-12-31 22:00:00        47.0     35.0         5.0         86.0   4.0
# 2018-12-31 23:00:00        42.0     15.0         4.0         69.0   4.0
#
# [72594 rows x 2756 columns]

# %%
import matplotlib.pyplot as plt

plt.hist(data[cur_station], bins=50)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma de valores')
plt.show()

# %%
columnas = data.columns
print(len(columnas))
# Out:
# 2756

# %%
data_cols = [col for col in data.columns]
print(data_cols)
# Out:
# ['U10_0_h0', 'U10_1_h0', 'U10_2_h0', 'U10_3_h0', 'U10_4_h0', 'U10_5_h0', 'U10_6_h0', 'U10_7_h0', 'U10_8_h0', 'U10_9_h0', 'U10_10_h0', 'U10_11_h0', 'U10_12_h0', 'U10_13_h0', 'U10_14_h0', 'U10_15_h0', 'V10_0_h0', 'V10_1_h0', 'V10_2_h0', 'V10_3_h0', 'V10_4_h0', 'V10_5_h0', 'V10_6_h0', 'V10_7_h0', 'V10_8_h0', 'V10_9_h0', 'V10_10_h0', 'V10_11_h0', 'V10_12_h0', 'V10_13_h0', 'V10_14_h0', 'V10_15_h0', 'RAINC_0_h0', 'RAINC_1_h0', 'RAINC_2_h0', 'RAINC_3_h0', 'RAINC_4_h0', 'RAINC_5_h0', 'RAINC_6_h0', 'RAINC_7_h0', 'RAINC_8_h0', 'RAINC_9_h0', 'RAINC_10_h0', 'RAINC_11_h0', 'RAINC_12_h0', 'RAINC_13_h0', 'RAINC_14_h0', 'RAINC_15_h0', 'T2_0_h0', 'T2_1_h0', 'T2_2_h0', 'T2_3_h0', 'T2_4_h0', 'T2_5_h0', 'T2_6_h0', 'T2_7_h0', 'T2_8_h0', 'T2_9_h0', 'T2_10_h0', 'T2_11_h0', 'T2_12_h0', 'T2_13_h0', 'T2_14_h0', 'T2_15_h0', 'RAINNC_0_h0', 'RAINNC_1_h0', 'RAINNC_2_h0', 'RAINNC_3_h0', 'RAINNC_4_h0', 'RAINNC_5_h0', 'RAINNC_6_h0', 'RAINNC_7_h0', 'RAINNC_8_h0', 'RAINNC_9_h0', 'RAINNC_10_h0', 'RAINNC_11_h0', 'RAINNC_12_h0', 'RAINNC_13_h0', 'RAINNC_14_h0', 'RAINNC_15_h0', 'SWDOWN_0_h0', 'SWDOWN_1_h0', 'SWDOWN_2_h0', 'SWDOWN_3_h0', 'SWDOWN_4_h0', 'SWDOWN_5_h0', 'SWDOWN_6_h0', 'SWDOWN_7_h0', 'SWDOWN_8_h0', 'SWDOWN_9_h0', 'SWDOWN_10_h0', 'SWDOWN_11_h0', 'SWDOWN_12_h0', 'SWDOWN_13_h0', 'SWDOWN_14_h0', 'SWDOWN_15_h0', 'GLW_0_h0
 'U10_9_h2', 'U10_10_h2', 'U10_11_h2', 'U10_12_h2', 'U10_13_h2', 'U10_14_h2', 'U10_15_h2', 'V10_0_h2', 'V10_1_h2', 'V10_2_h2', 'V10_3_h2', 'V10_4_h2', 'V10_5_h2', 'V10_6_h2', 'V10_7_h2', 'V10_8_h2', 'V10_9_h2', 'V10_10_h2', 'V10_11_h2', 'V10_12_h2', 'V10_13_h2', 'V10_14_h2', 'V10_15_h2', 'RAINC_0_h2', 'RAINC_1_h2', 'RAINC_2_h2', 'RAINC_3_h2', 'RAINC_4_h2', 'RAINC_5_h2', 'RAINC_6_h2', 'RAINC_7_h2', 'RAINC_8_h2', 'RAINC_9_h2', 'RAINC_10_h2', 'RAINC_11_h2', 'RAINC_12_h2', 'RAINC_13_h2', 'RAINC_14_h2', 'RAINC_15_h2', 'T2_0_h2', 'T2_1_h2', 'T2_2_h2', 'T2_3_h2', 'T2_4_h2', 'T2_5_h2', 'T2_6_h2', 'T2_7_h2', 'T2_8_h2', 'T2_9_h2', 'T2_10_h2', 'T2_11_h2', 'T2_12_h2', 'T2_13_h2', 'T2_14_h2', 'T2_15_h2', 'RAINNC_0_h2', 'RAINNC_1_h2', 'RAINNC_2_h2', 'RAINNC_3_h2', 'RAINNC_4_h2', 'RAINNC_5_h2', 'RAINNC_6_h2', 'RAINNC_7_h2', 'RAINNC_8_h2', 'RAINNC_9_h2', 'RAINNC_10_h2', 'RAINNC_11_h2', 'RAINNC_12_h2 ...

# %%
# Asegurar columna cur_station al final del DataFrame para normalización
columna = data.pop(f"{cur_station}")
data[f"{cur_station}"] = columna

config[ModelParams.INPUT_SIZE] = len(data.columns)
print(F'Data shape: {data.shape} Data axes {data.axes}')
print("Done!")

# Normalizar datos
print("Normalizing data....")
datetimes_str = data.index.values
datetimes = np.array([datetime.strptime(x, constants.datetime_format.value) for x in datetimes_str])

if norm_type == NormParams.min_max:
    scaler = preprocessing.MinMaxScaler()
if norm_type == NormParams.mean_zero:
    scaler = preprocessing.StandardScaler()

scaler = scaler.fit(data)
scaler_training = scaler
data_norm_np = scaler.transform(data)
data_norm_df = DataFrame(data_norm_np, columns=data.columns, index=data.index)
print(F'Done!')

# Filtrar fechas donde hay datos "forecasted hours after" (24 horas después)
print(F"Building X and Y ....")
accepted_times_idx = []
y_times_idx = []
for i, c_datetime in enumerate(datetimes):
    forecasted_datetime = (c_datetime + timedelta(hours=forecasted_hours))
    if forecasted_datetime in datetimes:
        accepted_times_idx.append(i)
        y_times_idx.append(np.argwhere(forecasted_datetime == datetimes)[0][0])

X_df = data_norm_df.loc[datetimes_str[accepted_times_idx]]
Y_df = data_norm_df.loc[datetimes_str[y_times_idx]][cur_station]
X = X_df.values
Y = Y_df.values

# Preparación previa al gráfico de histograma
print('Pre bootstrap')
import matplotlib.pyplot as plt

# Definir el índice de la columna a graficar
column_index = -1

plt.hist(X[:, column_index], bins=50)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma de valores')
plt.show()
# Out:
# Data shape: (72594, 2756) Data axes [Index(['2010-01-01 00:00:00', '2010-01-01 01:00:00', '2010-01-01 02:00:00',
#        '2010-01-01 03:00:00', '2010-01-01 04:00:00', '2010-01-01 05:00:00',
#        '2010-01-01 06:00:00', '2010-01-01 07:00:00', '2010-01-01 08:00:00',
#        '2010-01-01 09:00:00',
#        ...
#        '2018-12-31 14:00:00', '2018-12-31 15:00:00', '2018-12-31 16:00:00',
#        '2018-12-31 17:00:00', '2018-12-31 18:00:00', '2018-12-31 19:00:00',
#        '2018-12-31 20:00:00', '2018-12-31 21:00:00', '2018-12-31 22:00:00',
#        '2018-12-31 23:00:00'],
#       dtype='object', name='fecha', length=72594), Index(['U10_0_h0', 'U10_1_h0', 'U10_2_h0', 'U10_3_h0', 'U10_4_h0', 'U10_5_h0',
#        'U10_6_h0', 'U10_7_h0', 'U10_8_h0', 'U10_9_h0',
#        ...
#        'MER_hm23', 'cont_pmco', 'cont_pmdoscinco', 'cont_nox', 'cont_co',
#        'cont_nodos', 'cont_no', 'cont_sodos', 'cont_pmdiez', 'MER'],
#       dtype='object', length=2756)]
# Done!
# Normalizing data....
# /tmp/ipykernel_3473445/2276559697.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{cur_station}"] = columna
# Done!
# Building X and Y ....
# Pre bootstrap

# %%
# Definir el índice de la columna a graficar último índice corresponde con cur_station
column_index = -1

plt.hist(X[:, column_index], bins=50)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma de valores')
plt.show()

# %%
bootstrap = False
bootstrap_perc = 0
if perc_size > 0:
    bootstrap = True
    bootstrap_perc = perc_size

boostrap_factor = 15  # Number of times to repeat the bootstrap
percentiles = X_df[cur_station].quantile([bootstrap_perc])  # Obtain el percentil
print(percentiles) # target 2.3 ~ 90 ppm O_3
# Out:
# 0.97    2.459032
# Name: MER, dtype: float64

# %%
if bootstrap:
    # -------- Bootstrapping the data
    print("Bootstrapping the data...")
    percentiles = X_df[cur_station].quantile([bootstrap_perc])  # Obtain the percentile
    idxs_x = X[:,-1] > percentiles[bootstrap_perc]  # Obtain the indexes of the percentile for current time
    idxs_y = Y > percentiles[bootstrap_perc]  # Obtain the indexes of the percentile for the forecasted time
    idxs = idxs_y | idxs_x  # Merge both cases (we boostrap if the current time or the forecasted time are in the percentile)
    X_temp = X.copy()
    Y_temp = Y.copy()
    for i in range(boostrap_factor):
        X = np.concatenate((X, X_temp[idxs]))
        Y = np.concatenate((Y, Y_temp[idxs]))
        
import matplotlib.pyplot as plt

# Definir el índice de la columna a graficar
column_index = -1
print('After bootstrap')
plt.hist(X[:, column_index], bins=50)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma de valores')
plt.show()
# Out:
# Bootstrapping the data...
# After bootstrap

# %%
print("Done!")
print(F'X shape: {X.shape} Y shape: {Y.shape}')

tot_examples = X.shape[0]
rows_to_read = np.arange(tot_examples)
# Out:
# Done!
# X shape: (117049, 2756) Y shape: (117049,)

# %%
# Datos escalados:
data_norm_df
# Out:
#                      U10_0_h0  U10_1_h0  U10_2_h0  U10_3_h0  U10_4_h0  \
-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# [-0.8932741  -0.8932741  -0.8932741  ...  1.83277676  1.94329234
#   0.65394396]

# %%
# ================ Split definition =================
[train_ids, val_ids, test_ids] = utilsNN.split_train_validation_and_test(tot_examples,
                                                                         val_percentage=val_perc,
                                                                         test_percentage=test_perc,
                                                                         shuffle_ids=False)

print("Train examples (total:{}) :{}".format(len(train_ids), rows_to_read[train_ids]))
print("Validation examples (total:{}) :{}:".format(len(val_ids), rows_to_read[val_ids]))
print("Test examples (total:{}) :{}".format(len(test_ids), rows_to_read[test_ids]))

now = datetime.utcnow().strftime("%Y_%m_%d_%H_%M")
model_name = F'{model_name_user}_{cur_pollutant}_{cur_station}_{now}'

print(f"Model Name :\n{model_name}")
# Out:
# Train examples (total:105344) :[     0      1      2 ... 105341 105342 105343]
# Validation examples (total:11705) :[105344 105345 105346 ... 117046 117047 117048]:
# Test examples (total:0) :[]
# Model Name :
# 2023_MER_0_97_t_t_cont_otres_MER_2023_05_04_18_28

# %%
# # ================ Scaler training saving =================
import pickle

path_file = join(output_folder,F"{model_name}_scaler.pkl")

# Guarda el scaler en un archivo
with open(path_file, 'wb') as f:
    pickle.dump(scaler, f)

print(path_file)
# Out:
# /ZION/AirPollutionData/Data/Training/pmt-TE-2010-2018-v2019_r0v3_cr35/cont_otres_MER/2023_MER_0_97_t_t_cont_otres_MER_2023_05_04_18_28_scaler.pkl

# %%
# ******************* Selecting the model **********************
model = select_1d_model(config)
plot_model(model, to_file=join(output_folder, F'{model_name}.png'), show_shapes=True)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2756)]            0
#
#  input_layer (Dense)         (None, 300)               827100
#
#  hidden_1 (Dense)            (None, 300)               90300
#
#  batch_normalization (BatchN  (None, 300)              1200
#  ormalization)
#
#  dropout (Dropout)           (None, 300)               0
#
#  hidden_2 (Dense)            (None, 200)               60200
#
#  batch_normalization_1 (Batc  (None, 200)              800
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  hidden_3 (Dense)            (None, 100)               20100
#
#  batch_normalization_2 (Batc  (None, 100)              400
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  hidden_4 (Dense)            (None, 100)               10100
#
#  batch_normalization_3 (Batc  (None, 100)              400
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  hidden_5 (Dense)            (None, 100)               10100
#
#  batch_normalization_4 (Batc  (None, 100)              400
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  hidden_6 (Dense)            (None, 100)               10100
#
#  batch_normalization_5 (Batc  (None, 100)              400
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  hidden_7 (Dense)            (None, 100)               10100
#
#  batch_normalization_6 (Batc  (None, 100)              400
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 100)               0
#
#  hidden_8 (Dense)            (None, 100)               10100
#
#  batch_normalization_7 (Batc  (None, 100)              400
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 100)               0
#
#  output_layer (Dense)        (None, 1)                 101
#
# =================================================================
# Total params: 1,052,701
# Trainable params: 1,050,501
# Non-trainable params: 2,200
# _________________________________________________________________

# %%
print("Saving split information...")

file_name_splits = join(split_info_folder, F'{model_name}.csv')
info_splits = DataFrame({F'Train({len(train_ids)})': train_ids})
info_splits[F'Validation({len(val_ids)})'] = 0
info_splits[F'Validation({len(val_ids)})'][0:len(val_ids)] = val_ids
info_splits[F'Test({len(test_ids)})'] = 0
info_splits[F'Test({len(test_ids)})'][0:len(test_ids)] = test_ids
info_splits.to_csv(file_name_splits, index=None)

print(F"Norm params: {scaler.get_params()}")
file_name_normparams = join(parameters_folder, F'{model_name}.csv')
utilsNN.save_norm_params(file_name_normparams, norm_type, scaler)
info_splits.to_csv(file_name_splits, index=None)

print("Getting callbacks ...")

[logger, save_callback, stop_callback] = utilsNN.get_all_callbacks(model_name=model_name,
                                                                   early_stopping_func=F'val_{eval_metrics[0].__name__}',
                                                                   weights_folder=weights_folder,
                                                                   logs_folder=logs_folder,patience=150)

print("Training setup ...")
# This part should be somehow separated, it will change for every project
x_train = X[train_ids, :]
y_train = Y[train_ids]
x_val = X[val_ids, :]
y_val = Y[val_ids]
x_test = X[test_ids, :]
y_test = Y[test_ids]

# ------------------- Plotting some intermediate results
size = 24 * 10 # 10 days of data
start = np.random.randint(0, len(data) - size)
end = start + size
plt.figure(figsize=[64, 8])
x_plot = range(len(X_df.iloc[start:end].index.values))
y_plot = X_df.iloc[start:end][cur_station].values
yy_plot = Y_df.iloc[start:end].values

fig, ax = plt.subplots(1,1,figsize=(10,4))
ax.plot(x_plot, y_plot, color='r', label='Current')
ax.plot(x_plot, yy_plot, color='b',  label='Desired')
ax.set_title = F"{cur_pollutant}_{cur_station}"
plt.legend()
plt.show()
# ------------------- Done Plotting some intermediate results
# Out:
# Saving split information...
# Norm params: {'copy': True, 'with_mean': True, 'with_std': True}
# Saving normalization parameters....
# Getting callbacks ...
# The early stopping callback is in auto mode
# Training setup ...

# %%
# Asignar el modelo existente a la variable model_1 dentro del bloque with strategy.scope()
with strategy.scope():
    model = select_1d_model(config)

    # Compilar el modelo    
    print("Compiling model ...")
    model.compile(loss=loss_func, optimizer=optimizer, metrics=eval_metrics)

    # Entrenar el modelo
    model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_val, y_val),
                    shuffle=True,
                    callbacks=[logger, save_callback, stop_callback])
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Compiling model ...
# Epoch 1/5000
# 2023-05-04 12:28:45.771282: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_1911"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\020FlatMapDataset:4"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# experimental_type {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_DATASET
#     args {
#       type_id: TFT_PRODUCT
#       args {
#         type_id: TFT_TENSOR
#         args {
#           type_id: TFT_INT64
#         }
#       }
#     }
#   }
#   args {
#     type_id: TFT_DATASET
#     args {
#       type_id: TFT_PRODUCT
#       args {
#         type_id: TFT_TENSOR
#         args {
#           type_id: TFT_INT64
#         }
#       }
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# INFO:tensorflow:batch_all_reduce: 36 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 36 all-reduces with algorithm = nccl, num_packs = 1
# 105/106 [============================>.] - ETA: 0s - loss: 6.6524 - mean_squared_error: 6.6524
# 2023-05-04 12:28:56.895147: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:776] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_9"
# op: "FlatMapDataset"
# input: "PrefetchDataset/_8"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: -2
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_slice_batch_indices_11212"
#     }
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\021FlatMapDataset:34"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_INT64
#     }
#   }
# }
# experimental_type {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_DATASET
#     args {
#       type_id: TFT_PRODUCT
#       args {
#         type_id: TFT_TENSOR
#         args {
#           type_id: TFT_INT64
#         }
#       }
#     }
#   }
#   args {
#     type_id: TFT_DATASET
#     args {
#       type_id: TFT_PRODUCT
#       args {
#         type_id: TFT_TENSOR
#         args {
#           type_id: TFT_INT64
#         }
#       }
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 106/106 [==============================] - 13s 46ms/step - loss: 6.6445 - mean_squared_error: 6.6445 - val_loss: 3.4989 - val_mean_squared_error: 3.4989
# Epoch 2/5000
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2125 - mean_squared_error: 0.2125 - val_loss: 0.0278 - val_mean_squared_error: 0.0278
# Epoch 979/5000
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2143 - mean_squared_error: 0.2143 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 980/5000
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2119 - mean_squared_error: 0.2119 - val_loss: 0.0380 - val_mean_squared_error: 0.0380
# Epoch 981/5000
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2131 - mean_squared_error: 0.2131 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 982/5000
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2164 - mean_squared_error: 0.2164 - val_loss: 0.0320 - val_mean_squared_error: 0.0320
# Epoch 983/5000
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2132 - mean_squared_error: 0.2132 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 984/5000
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2169 - mean_squared_error: 0.2169 - val_loss: 0.0299 - val_mean_squared_error: 0.0299
# Epoch 985/5000
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2151 - mean_squared_error: 0.2151 - val_loss: 0.0322 - val_mean_squared_error: 0.0322
# Epoch 986/5000
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2116 - mean_squared_error: 0.2116 - val_loss: 0.0297 - val_mean_squared_error: 0.0297
# Epoch 987/5000
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2121 - mean_squared_error: 0.2121 - val_loss: 0.0365 - val_mean_squared_error: 0.0365
# Epoch 988/5000
# 106/106 [==============================] - 3s 26ms/step - loss: 0.2124 - mean_squared_error: 0.2124 - val_loss: 0.0305 - val_mean_squared_error: 0.0305
# Epoch 989/5000
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2129 - mean_squared_error: 0.2129 - val_loss: 0.0368 - val_mean_squared_error: 0.0368
# Epoch 990/5000
# 106/106 [==============================] - 3s 25ms/step - loss: 0.2120 - mean_squared_error: 0.2120 - val_loss: 0.0305 - val_mean_squared_error: 0.0305

# %%
# Alarma de fin de entrenamiento XD
# *---------- sonido de alarma para sonar cuando se acaba el entrenamiento ----------*
import numpy as np
from IPython.display import Audio

# Definir la frecuencia del tono principal (880 Hz para La agudo)
freq1 = 880

# Crear una secuencia de muestras para el tono principal que dura 0.5 segundos
duration1 = 0.5 # segundos
sampling_rate = 44100 # Hz
t1 = np.linspace(0, duration1, int(duration1 * sampling_rate), False)
tones1 = np.sin(2 * np.pi * freq1 * t1)

# Definir la frecuencia del tono secundario (440 Hz para La)
freq2 = 440

# Crear una secuencia de muestras para el tono secundario que dura 0.5 segundos
duration2 = 0.5 # segundos
t2 = np.linspace(0, duration2, int(duration2 * sampling_rate), False)
tones2 = np.abs(np.mod(t2, 1./freq2)*freq2*2-1)-0.5

# Concatenar tres copias del arreglo de tonos
tones = np.concatenate((tones1, tones2), axis=None)
tones = np.concatenate((tones, tones, tones), axis=None)

# Reproducir el sonido de timbre tres veces
Audio(tones, rate=sampling_rate, autoplay=True)

# ---------- Fin de alarma
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(loss_func)
print(optimizer)
print(eval_metrics)
# Out:
# <function mean_squared_error at 0x7f576fa14c10>
# <keras.optimizer_v2.adam.Adam object at 0x7f585985f7f0>
# [<function mean_squared_error at 0x7f576fa14c10>]

# %%
model

# %% [markdown]
# # Evaluation

# %%
import tensorflow as tf
import tensorflow.keras.metrics as metrics
import tensorflow.keras.losses as losses
from tensorflow.keras.optimizers import *
from ai_common.constants.AI_params import ModelParams, AiModels, TrainingParams, ClassificationParams, VisualizationResultsParams, NormParams


def select_available_gpus(num_gpus, memory_limit=7168):
    # Obtener la lista de todas las GPUs disponibles
    gpus = tf.config.list_physical_devices('GPU')
    if not gpus:
        return []
    
    # Seleccionar las primeras 'num_gpus' GPUs
    selected_gpus = gpus[:num_gpus]
    
    # Configurar TensorFlow para usar las GPUs seleccionadas
    try:
        tf.config.experimental.set_visible_devices(selected_gpus, 'GPU')
        for gpu in selected_gpus:
            tf.config.experimental.set_virtual_device_configuration(
                gpu, [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)])
            tf.config.experimental.set_memory_growth(gpu, True)
        return selected_gpus
    except RuntimeError as e:
        print(e)
        return []

try:
    #selected_gpus = select_available_gpus(2)
    #print(f"Se han seleccionado {len(selected_gpus)} GPUs con 7.375 GB de memoria cada una.")
    # Configuración de la estrategia de distribución en GPUs
    strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"])
    print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

except ValueError as e:
    print(e)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2

# %%
import sys
sys.path.append('/home/pedro/git2/otro2/air_pollution_forecast/eoas_pyutils')
sys.path.append('/home/pedro/git2/otro2/air_pollution_forecast/')

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from os.path import join
from datetime import date, datetime, timedelta
from sklearn import preprocessing

import scrapbook as sb
from ai_common.constants.AI_params import NormParams, TrainingParams, ModelParams
import ai_common.training.trainingutils as utilsNN
from ai_common.models.modelSelector import select_1d_model
from viz_utils.eoa_viz import EOAImageVisualizer
from io_utils.io_common import create_folder
from conf.localConstants import constants
from conf.TrainingUserConfiguration import getTrainingParams
from conf.params import LocalTrainingParams


# Function definitions

def select_available_gpus(num_gpus, memory_limit=7168):
    # Obtener la lista de todas las GPUs disponibles
    gpus = tf.config.list_physical_devices('GPU')
    if not gpus:
        return []
    
    # Seleccionar las primeras 'num_gpus' GPUs
    selected_gpus = gpus[:num_gpus]
    
    # Configurar TensorFlow para usar las GPUs seleccionadas
    try:
        tf.config.experimental.set_visible_devices(selected_gpus, 'GPU')
        for gpu in selected_gpus:
            tf.config.experimental.set_virtual_device_configuration(
                gpu, [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=memory_limit)])
            tf.config.experimental.set_memory_growth(gpu, True)
        return selected_gpus
    except RuntimeError as e:
        print(e)
        return []
    

def append_model_params(cur_config):
    model_config = {
        ModelParams.MODEL: AiModels.ML_PERCEPTRON,
        ModelParams.DROPOUT: True,
        ModelParams.BATCH_NORMALIZATION: True,
        #ModelParams.CELLS_PER_HIDDEN_LAYER: [300, 50],
        # ModelParams.CELLS_PER_HIDDEN_LAYER: [300, 300, 300],
        ModelParams.CELLS_PER_HIDDEN_LAYER: [300, 300, 200, 100, 100, 100, 100, 100, 100],
        ModelParams.NUMBER_OF_OUTPUT_CLASSES: 1,
        ModelParams.ACTIVATION_HIDDEN_LAYERS: 'relu',
        ModelParams.ACTIVATION_OUTPUT_LAYERS: None
    }
    model_config[ModelParams.HIDDEN_LAYERS] = len(model_config[ModelParams.CELLS_PER_HIDDEN_LAYER])
    return {**cur_config, **model_config}

def getTrainingParams2():
    cur_config = {
        TrainingParams.input_folder: join(data_folder, constants.merge_output_folder.value, merged_specific_folder),
        TrainingParams.output_folder: F"{join(data_folder, constants.training_output_folder.value,f'{test_str}')}",        
        TrainingParams.validation_percentage: .1,
        TrainingParams.test_percentage: 0, # We will test with a diferent day
        TrainingParams.evaluation_metrics: [metrics.mean_squared_error],  # Metrics to show in tensor flow in the training
        TrainingParams.loss_function: losses.mean_squared_error,  # Loss function to use for the learning
        
        #TrainingParams.evaluation_metrics: [metrics.mean_squared_logarithmic_error], #mean_squared_error],  # Metrics to show in tensor flow in the training
        #TrainingParams.loss_function: losses.mean_squared_logarithmic_error, # PS_test:losses.mean_squared_error,  # Loss function to use for the learning

        # TrainingParams.loss_function: metrics.mean_squared_error,  # Loss function to use for the learning
        TrainingParams.optimizer: Adam(), #learning_rate=0.0005,beta_1=0.99,beta_2=0.999,epsilon=1e-07),#),  # Default values lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None,
        TrainingParams.batch_size: batch_size, #200,
        TrainingParams.epochs: 5000,
        TrainingParams.config_name: _run_name,
        TrainingParams.data_augmentation: False,
        TrainingParams.normalization_type: NormParams.mean_zero,
        LocalTrainingParams.stations: stations_2020,
        LocalTrainingParams.pollutants: ["cont_otres"],
        LocalTrainingParams.forecasted_hours: 24,
        LocalTrainingParams.tot_num_quadrants: 64,  # 8x8
        LocalTrainingParams.num_hours_in_netcdf: 24,
        LocalTrainingParams.years: range(start_year, end_year),
        LocalTrainingParams.debug: _debug,
        LocalTrainingParams.filter_dates: filter_training_hours
    }
    return append_model_params(cur_config)

# Variable definitions
data_folder = '/ZION/AirPollutionData/Data/'
grid_size = 4
merged_specific_folder = f'{grid_size*grid_size}'
_run_name = F'2023_{test_identifier}'
stations_2020 = ["UIZ", "AJU", "ATI", "CUA", "SFE", "SAG", "CUT", "PED", "TAH", "GAM", "IZT", "CCA", "HGM", "LPR",
                 "MGH", "CAM", "FAC", "TLA", "MER", "XAL", "LLA", "TLI", "UAX", "BJU", "MPA",
                 "MON", "NEZ", "INN", "AJM", "VIF"]
_debug = False
filter_training_hours = False
start_year = 2010
end_year = 2018
cur_pollutant = 'cont_otres'
all_stations = ["UIZ", "AJU", "ATI", "CUA", "SFE", "SAG", "CUT", "PED", "TAH", "GAM", "IZT", "CCA", "HGM", "LPR",
                "MGH", "CAM", "FAC", "TLA", "MER", "XAL", "LLA", "TLI", "UAX", "BJU", "MPA",
                "MON", "NEZ", "INN", "AJM", "VIF"]
test_year = 2019

# TensorFlow configuration
try:
    strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"])
    print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
except ValueError as e:
    print(e)

# Load configuration and print values
config = getTrainingParams2()
stations = ['UIZ', 'CUA', 'PED', 'CCA']
pollutants = config[LocalTrainingParams.pollutants]


print("config values:\n")
for key, value in config.items():
    print(f"{key} : {value}")

print(f"""

stations: {stations}

pollutants: {pollutants}

start_year: {start_year}

end_year: {end_year}
""")
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2
# config values:
#
# TrainingParams.input_folder : /ZION/AirPollutionData/Data/MergedDataCSV/16
# TrainingParams.output_folder : /ZION/AirPollutionData/Data/Training/pmt-TE-2010-2018-v2019_r0v3_cr35
# TrainingParams.validation_percentage : 0.1
# TrainingParams.test_percentage : 0
# TrainingParams.evaluation_metrics : [<function mean_squared_error at 0x7f576fa14c10>]
# TrainingParams.loss_function : <function mean_squared_error at 0x7f576fa14c10>
# TrainingParams.optimizer : <keras.optimizer_v2.adam.Adam object at 0x7f541b5b91e0>
# TrainingParams.batch_size : 1000
# TrainingParams.epochs : 5000
# TrainingParams.config_name : 2023_MER_0_97_t_t
# TrainingParams.data_augmentation : False
# TrainingParams.normalization_type : NormParams.mean_zero
# LocalTrainingParams.stations : ['UIZ', 'AJU', 'ATI', 'CUA', 'SFE', 'SAG', 'CUT', 'PED', 'TAH', 'GAM', 'IZT', 'CCA', 'HGM', 'LPR', 'MGH', 'CAM', 'FAC', 'TLA', 'MER', 'XAL', 'LLA', 'TLI', 'UAX', 'BJU', 'MPA', 'MON', 'NEZ', 'INN', 'AJM', 'VIF']
# LocalTrainingParams.pollutants : ['cont_otres']
# LocalTrainingParams.forecasted_hours : 24
# LocalTrainingParams.tot_num_quadrants : 64
# LocalTrainingParams.num_hours_in_netcdf : 24
# LocalTrainingParams.years : range(2010, 2018)
# LocalTrainingParams.debug : False
# LocalTrainingParams.filter_dates : False
# ModelParams.MODEL : AiModels.ML_PERCEPTRON
# ModelParams.DROPOUT : True
# ModelParams.BATCH_NORMALIZATION : True
# ModelParams.CELLS_PER_HIDDEN_LAYER : [300, 300, 200, 100, 100, 100, 100, 100, 100]
# ModelParams.NUMBER_OF_OUTPUT_CLASSES : 1
# ModelParams.ACTIVATION_HIDDEN_LAYERS : relu
# ModelParams.ACTIVATION_OUTPUT_LAYERS : None
# ModelParams.HIDDEN_LAYERS : 9
#
#
# stations: ['UIZ', 'CUA', 'PED', 'CCA']
#
# pollutants: ['cont_otres']
#
# start_year: 2010
#
# end_year: 2018

# %%
config[ModelParams.INPUT_SIZE] = 2756 # len(data.columns)
forecasted_hours = 24
model = select_1d_model(config)

# %%
## Para usar en caso de recargado del modelo, revisar los siguientes datos:
#path_file = '/ZION/AirPollutionData/Data/Training/pmt-TE-2010-2018-v2019_r0v3_cr34/cont_otres_MER/2023_MER_0_97_t_t_cont_otres_MER_2023_05_02_16_16_scaler.pkl'
#model_name = '2023_MER_0_97_t_t_cont_otres_MER_2023_05_02_16_16'
#output_folder = '/ZION/AirPollutionData/Data/Training/pmt-TE-2010-2018-v2019_r0v3_cr34/cont_otres_MER/'

# %%
data_folder = '/ZION/AirPollutionData/Data/MergedDataCSV/16/'
input_file = join(data_folder,f"{test_year}_cont_otres_AllStations.csv")
data = pd.read_csv(input_file, index_col=0)
# -------- Removing not used stations
#remove_columns = [x for x in all_stations if x.find(cur_station) == -1]
#data = data.drop(columns=remove_columns)
# -------- Remove nans

remove_columns = [x for x in all_stations if x.find(cur_station) == -1]
data.loc[:,remove_columns] = data.loc[:,remove_columns].fillna(-200)
data = data.dropna()

# Se agregan las ultimas 23 horas de contaminantes al dataset como hm1 -> menos 1hr, ...
# Iteramos sobre el DataFrame usando iterrows()
for index, row in data.iterrows():
    #print(index, row['TLA'])
    dt_row = datetime.strptime(index, constants.datetime_format.value)
    for i in range(24):
        dt_target = dt_row - timedelta(hours=i)
        dt_target_str = dt_target.strftime('%Y-%m-%d %H:%M:%S')
        if dt_target_str in data.index:
            temp_val = data.loc[dt_target_str][f'{cur_station}']
        else:
            temp_val = np.nan
        data.loc[f'{index}', f'{cur_station}_hm{i}'] = temp_val

# moviendo columna cur_station al final del data frame para considerarlo asi en normalizacion scaler
columna = data.pop(f"{cur_station}")
data[f"{cur_station}"] = columna
#data.pop(f"{cur_station}_hm0") # Se remueve datos repetidos en cur_station


data = data.fillna(-200)

# concatenar columnas contaminantes
import pandas as pd
import glob
import re

def load_dataframes(input_folder, regex):
    file_names = glob.glob(input_folder + "/*")
    dataframes = {}
    
    for file_name in file_names:
        match = re.search(regex, file_name)
        
        if match:
            key = match.group(1)
            df = pd.read_csv(file_name, index_col=0)
            df = df.loc['2010-01-01':]
            df = df[~df.index.duplicated()]
            
            if key == 'otres_':
                continue
            
            if key in dataframes:
                dataframes[key] = pd.concat([dataframes[key], df], axis=1)
            else:
                dataframes[key] = df
                
    return dataframes

input_folder = "/ZION/AirPollutionData/Data/DataPollutionDB_CSV"
regex = f"cont_(.*?){cur_station}\.csv"

print(f'Buscando con la expresión regular: {regex}')

dataframes = load_dataframes(input_folder, regex)
data_cont = pd.concat(dataframes.values(), axis=1)
data_cont = data_cont[~data_cont.index.duplicated()]
data_cont.fillna(-200)


# Seleccionar todas las columnas de data_cont
data_cont_cols = data_cont.columns

# Concatenar todas las columnas de data_cont con data
data = pd.concat([data, data_cont[data_cont_cols]], axis=1)
#data = data.dropna()
data = data.dropna(subset=[cur_station])
data.fillna(-200, inplace=True)
# moviendo columna cur_station al final del data frame para considerarlo asi en normalizacion scaler
columna = data.pop(f"{cur_station}")
data[f"{cur_station}"] = columna
###

# moviendo columna cur_station al final del data frame para considerarlo asi en normalizacion scaler
columna = data.pop(f"{cur_station}")
data[f"{cur_station}"] = columna
###

config[ModelParams.INPUT_SIZE] = len(data.columns)
print(F'Data shape: {data.shape} Data axes {data.axes}')
print("Done!")

# Predicting for the next value after 24hrs (only one)
print("Normalizing data....")
# TODO we need to normalize by reading the parameters from the training
# norm_file = "/data/PollutionData/Training/Parameters/2023_cont_otres_UIZ_2023_02_14_21_19.csv"
datetimes_str = data.index.values
datetimes = np.array([datetime.strptime(x, constants.datetime_format.value) for x in datetimes_str])
scaler = None

#scaler = preprocessing.MinMaxScaler()
#scaler = scaler.fit(data)
#scaler = scaler_training  # <- Para corregir escalamiento.

import pickle

#path_file = join(output_folder,F"scaler.pkl")
#path_file = join(output_folder,F"{model_name}_scaler.pkl")

print(path_file)
# Guarda el scaler en un archivo
#with open(path_file, 'wb') as f:
#    pickle.dump(scaler, f)


# Carga el scaler desde un archivo
with open(path_file, 'rb') as f:
    scaler = pickle.load(f)

data_norm_np = scaler.transform(data)
data_norm_df = pd.DataFrame(data_norm_np, columns=data.columns, index=data.index)
print(F'Done!')

# Filtering only dates where there is data "forecasted hours after" (24 hrs after)
print(F"\tBuilding X and Y ....")
accepted_times_idx = []
y_times_idx = []
for i, c_datetime in enumerate(datetimes):
    forecasted_datetime = (c_datetime + timedelta(hours=forecasted_hours))
    if forecasted_datetime in datetimes:
        accepted_times_idx.append(i)
        y_times_idx.append(np.argwhere(forecasted_datetime == datetimes)[0][0])

X_df = data_norm_df.loc[datetimes_str[accepted_times_idx]]
Y_df = data_norm_df.loc[datetimes_str[y_times_idx]][cur_station]
X = X_df.values
Y = Y_df.values

print(F'X shape: {X.shape} Y shape: {Y.shape}')
# Out:
# /tmp/ipykernel_3473445/3009935148.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{cur_station}"] = columna
# Buscando con la expresión regular: cont_(.*?)MER\.csv
# /tmp/ipykernel_3473445/3009935148.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{cur_station}"] = columna
# /tmp/ipykernel_3473445/3009935148.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{cur_station}"] = columna
# Data shape: (8069, 2756) Data axes [Index(['2019-01-01 03:00:00', '2019-01-01 04:00:00', '2019-01-01 05:00:00',
#        '2019-01-01 06:00:00', '2019-01-01 07:00:00', '2019-01-01 08:00:00',
#        '2019-01-01 09:00:00', '2019-01-01 10:00:00', '2019-01-01 11:00:00',
#        '2019-01-01 12:00:00',
#        ...
#        '2019-12-30 15:00:00', '2019-12-30 16:00:00', '2019-12-30 17:00:00',
#        '2019-12-30 18:00:00', '2019-12-30 19:00:00', '2019-12-30 20:00:00',
#        '2019-12-30 21:00:00', '2019-12-30 22:00:00', '2019-12-30 23:00:00',
#        '2019-12-31 00:00:00'],
#       dtype='object', name='fecha', length=8069), Index(['U10_0_h0', 'U10_1_h0', 'U10_2_h0', 'U10_3_h0', 'U10_4_h0', 'U10_5_h0',
#        'U10_6_h0', 'U10_7_h0', 'U10_8_h0', 'U10_9_h0',
#        ...
#        'MER_hm23', 'cont_pmco', 'cont_pmdoscinco', 'cont_nox', 'cont_co',
#        'cont_nodos', 'cont_no', 'cont_sodos', 'cont_pmdiez', 'MER'],
#       dtype='object', length=2756)]
# Done!
# Normalizing data....
# /ZION/AirPollutionData/Data/Training/pmt-TE-2010-2018-v2019_r0v3_cr35/cont_otres_MER/2023_MER_0_97_t_t_cont_otres_MER_2023_05_04_18_28_scaler.pkl
# Done!
# 	Building X and Y ....
# X shape: (7641, 2756) Y shape: (7641,)

# %%
data
# Out:
#                      U10_0_h0  U10_1_h0  U10_2_h0  U10_3_h0  U10_4_h0  \
# fecha
# 2019-01-01 03:00:00     -1.98      1.02      1.01     -0.91      0.49
# 2019-01-01 04:00:00     -1.90      0.85      0.79     -0.83      0.03
# 2019-01-01 05:00:00     -1.77      1.11      1.01     -1.02     -0.28
# 2019-01-01 06:00:00     -0.82      1.86      1.03     -1.11      0.66
# 2019-01-01 07:00:00     -0.36      2.42      1.90     -0.22      1.28
# ...                       ...       ...       ...       ...       ...
# 2019-12-30 20:00:00      1.75      1.56      0.60     -0.22      0.53
# 2019-12-30 21:00:00      1.42      1.16      0.56     -0.57      0.32
# 2019-12-30 22:00:00      1.09      1.09      0.66     -0.20      0.57
# 2019-12-30 23:00:00      1.02      1.11      0.78      0.23      1.18
# 2019-12-31 00:00:00      0.29      0.38     -0.18      0.03      1.85
#
#                      U10_5_h0  U10_6_h0  U10_7_h0  U10_8_h0  U10_9_h0  ...  \
# fecha                                                                  ...
# 2019-01-01 03:00:00      0.68     -0.49     -2.29      1.55      1.94  ...
# 2019-01-01 04:00:00      0.49     -0.97     -2.98      1.92      1.89  ...
# 2019-01-01 05:00:00      0.75     -0.98     -3.67      1.31      2.13  ...
# 2019-01-01 06:00:00      1.13     -0.77     -3.69      1.52      2.17  ...
# 2019-01-01 07:00:00      0.96     -0.84     -2.98      1.09      1.33  ...
# ...                       ...       ...       ...       ...       ...  ...
# 2019-12-30 20:00:00     -0.48     -0.76      0.43     -0.44     -0.42  ...
# 2019-12-30 21:00:00      0.03     -1.28     -0.00     -0.21     -0.05  ...
# 2019-12-30 22:00:00      0.31     -1.69      0.02      0.46     -0.06  ...
# 2019-12-30 23:00:00      0.52     -1.74     -0.60      2.19     -0.56  ...
# 2019-12-31 00:00:00      2.11      0.74      0.34      3.54      4.28  ...
#
#                      MER_hm23  cont_pmco  cont_pmdoscinco  cont_nox  cont_co  \
# fecha
# 2019-01-01 03:00:00    -200.0       45.0             95.0      80.0     1.80
# 2019-01-01 04:00:00    -200.0       36.0             82.0      80.0     1.80
# 2019-01-01 05:00:00    -200.0       43.0            110.0      96.0     1.90
# 2019-01-01 06:00:00    -200.0       62.0            165.0      91.0     1.80
# 2019-01-01 07:00:00    -200.0       55.0            161.0     124.0     2.20
# ...                       ...        ...              ...       ...      ...
# 2019-12-30 20:00:00       8.0       17.0             18.0      53.0     0.99
# 2019-12-30 21:00:00       8.0       22.0             15.0      67.0     1.24
# 2019-12-30 22:00:00       5.0       21.0             22.0      65.0     1.19
# 2019-12-30 23:00:00       4.0       29.0             19.0      59.0     0.94
# 2019-12-31 00:00:00       4.0       27.0             24.0      63.0     1.07
#
#                      cont_nodos  cont_no  cont_sodos  cont_pmdiez  MER
# fecha
# 2019-01-01 03:00:00        36.0     43.0         6.0        141.0  3.0
# 2019-01-01 04:00:00        36.0     43.0         6.0        118.0  3.0
# 2019-01-01 05:00:00        39.0     57.0         7.0        154.0  4.0
# 2019-01-01 06:00:00        36.0     55.0         7.0        227.0  4.0
# 2019-01-01 07:00:00        34.0     89.0         6.0        216.0  3.0
# ...                         ...      ...         ...          ...  ...
# 2019-12-30 20:00:00        33.0     20.0         2.0         39.0  7.0
# 2019-12-30 21:00:00        39.0     28.0         2.0         35.0  4.0
# 2019-12-30 22:00:00        39.0     27.0         2.0         51.0  4.0
# 2019-12-30 23:00:00        36.0     22.0         2.0         45.0  5.0
# 2019-12-31 00:00:00        33.0     30.0         2.0         46.0  4.0
#
# [8069 rows x 2756 columns]

# %%
# Asumiendo que tu DataFrame se llama 'data'
column_names = data.columns

# Imprime el nombre de las columnas y su índice
for index, column_name in enumerate(column_names):
    print(f"Índice: {index}, Nombre de columna: {column_name}")

# Convierte el DataFrame a un NumPy array
numpy_array = data.to_numpy()
# Out:
# Índice: 0, Nombre de columna: U10_0_h0
# Índice: 1, Nombre de columna: U10_1_h0
# Índice: 2, Nombre de columna: U10_2_h0
# Índice: 3, Nombre de columna: U10_3_h0
# Índice: 4, Nombre de columna: U10_4_h0
# Índice: 5, Nombre de columna: U10_5_h0
# Índice: 6, Nombre de columna: U10_6_h0
# Índice: 7, Nombre de columna: U10_7_h0
# Índice: 8, Nombre de columna: U10_8_h0
# Índice: 9, Nombre de columna: U10_9_h0
# Índice: 10, Nombre de columna: U10_10_h0
# Índice: 11, Nombre de columna: U10_11_h0
# Índice: 12, Nombre de columna: U10_12_h0
# Índice: 13, Nombre de columna: U10_13_h0
# Índice: 14, Nombre de columna: U10_14_h0
# Índice: 15, Nombre de columna: U10_15_h0
# Índice: 16, Nombre de columna: V10_0_h0
# Índice: 17, Nombre de columna: V10_1_h0
# Índice: 18, Nombre de columna: V10_2_h0
# Índice: 19, Nombre de columna: V10_3_h0
# Índice: 20, Nombre de columna: V10_4_h0
# Índice: 21, Nombre de columna: V10_5_h0
# Índice: 22, Nombre de columna: V10_6_h0
# Índice: 23, Nombre de columna: V10_7_h0
# Índice: 24, Nombre de columna: V10_8_h0
# Índice: 25, Nombre de columna: V10_9_h0
# Índice: 26, Nombre de columna: V10_10_h0
# Índice: 27, Nombre de columna: V10_11_h0
# Índice: 28, Nombre de columna: V10_12_h0
# Índice: 29, Nombre de columna: V10_13_h0
# Índice: 30, Nombre de columna: V10_14_h0
# Índice: 31, Nombre de columna: V10_15_h0
# Índice: 32, Nombre de columna: RAINC_0_h0
# Índice: 33, Nombre de columna: RAINC_1_h0
# Índice: 34, Nombre de columna: RAINC_2_h0
# Índice: 35, Nombre de columna: RAINC_3_h0
# Índice: 36, Nombre de columna: RAINC_4_h0
# Índice: 37, Nombre de columna: RAINC_5_h0
# Índice: 38, Nombre de columna: RAINC_6_h0
# Índice: 97, Nombre de columna: GLW_1_h0
# Índice: 98, Nombre de columna: GLW_2_h0
# Índice: 99, Nombre de columna: GLW_3_h0
# Índice: 100, Nombre de columna: GLW_4_h0
# Índice: 101, Nombre de columna: GLW_5_h0
# Índice: 102, Nombre de columna: GLW_6_h0
# Índice: 103, Nombre de columna: GLW_7_h0
# Índice: 104, Nombre de columna: GLW_8_h0
# Índice: 105, Nombre de columna: GLW_9_h0
# Índice: 106, Nombre de columna: GLW_10_h0
# Índice: 107, Nombre de columna: GLW_11_h0
# Índice: 108, Nombre de columna: GLW_12_h0
# Índice: 109, Nombre de columna: GLW_13_h0
# Índice: 110, Nombre de columna: GLW_14_h0
# Índice: 111, Nombre de columna: GLW_15_h0
# Índice: 112, Nombre de columna: U10_0_h1
# Índice: 113, Nombre de columna: U10_1_h1
# Índice: 114, Nombre de columna: U10_2_h1
# Índice: 115, Nombre de columna: U10_3_h1
# Índice: 116, Nombre de columna: U10_4_h1
# Índice: 117, Nombre de columna: U10_5_h1
# Índice: 118, Nombre de columna: U10_6_h1
# Índice: 119, Nombre de columna: U10_7_h1
# Índice: 120, Nombre de columna: U10_8_h1
# Índice: 121, Nombre de columna: U10_9_h1
# Índice: 122, Nombre de columna: U10_10_h1
# Índice: 123, Nombre de columna: U10_11_h1
# Índice: 124, Nombre de columna: U10_12_h1
# Índice: 125, Nombre de columna: U10_13_h1
# Índice: 126, Nombre de columna: U10_14_h1
# Índice: 127, Nombre de columna: U10_15_h1
# Índice: 128, Nombre de columna: V10_0_h1
# Índice: 129, Nombre de columna: V10_1_h1
# Índice: 130, Nombre de columna: V10_2_h1
# Índice: 131, Nombre de columna: V10_3_h1
# Índice: 132, Nombre de columna: V10_4_h1
# Índice: 133, Nombre de columna: V10_5_h1
# Índice: 134, Nombre de columna: V10_6_h1
# Índice: 135, Nombre de columna: V10_7_h1
# Índice: 136, Nombre de columna: V10_8_h1
# Índice: 137, Nombre de columna: V10_9_h1
# Índice: 138, Nombre de columna: V10_10_h1
# Índice: 139, Nombre de columna: V10_11_h1
# Índice: 140, Nombre de columna: V10_12_h1
# Índice: 141, Nombre de columna: V10_13_h1
# Índice: 142, Nombre de columna: V10_14_h1
# Índice: 143, Nombre de columna: V10_15_h1
# Índice: 144, Nombre de columna: RAINC_0_h1
# Índice: 145, Nombre de columna: RAINC_1_h1
# Índice: 146, Nombre de columna: RAINC_2_h1
# Índice: 147, Nombre de columna: RAINC_3_h1
# Índice: 148, Nombre de columna: RAINC_4_h1
# Índice: 149, Nombre de columna: RAINC_5_h1
# Índice: 150, Nombre de columna: RAINC_6_h1
# Índice: 151, Nombre de columna: RAINC_7_h1
# Índice: 152, Nombre de columna: RAINC_8_h1
# Índice: 153, Nombre de columna: RAINC_9_h1
# Índice: 154, Nombre de columna: RAINC_10_h1
# Índice: 155, Nombre de columna: RAINC_11_h1
# Índice: 156, Nombre de columna: RAINC_12_h1
# Índice: 157, Nombre de columna: RAINC_13_h1
# Índice: 158, Nombre de columna: RAINC_14_h1
# Índice: 159, Nombre de columna: RAINC_15_h1
# Índice: 160, Nombre de columna: T2_0_h1
# Índice: 161, Nombre de columna: T2_1_h1
# Índice: 162, Nombre de columna: T2_2_h1
# Índice: 163, Nombre de columna: T2_3_h1
# Índice: 164, Nombre de columna: T2_4_h1
# Índice: 165, Nombre de columna: T2_5_h1
# Índice: 166, Nombre de columna: T2_6_h1
# Índice: 167, Nombre de columna: T2_7_h1
# Índice: 168, Nombre de columna: T2_8_h1
# Índice: 169, Nombre de columna: T2_9_h1
# Índice: 170, Nombre de columna: T2_10_h1
# Índice: 171, Nombre de columna: T2_11_h1
# Índice: 172, Nombre de columna: T2_12_h1
# Índice: 173, Nombre de columna: T2_13_h1
# Índice: 174, Nombre de columna: T2_14_h1
# Índice: 175, Nombre de columna: T2_15_h1
# Índice: 176, Nombre de columna: RAINNC_0_h1
# Índice: 177, Nombre de columna: RAINNC_1_h1
# Índice: 178, Nombre de columna: RAINNC_2_h1
# Índice: 179, Nombre de columna: RAINNC_3_h1
# Índice: 180, Nombre de columna: RAINNC_4_h1
# Índice: 181, Nombre de columna: RAINNC_5_h1
# Índice: 182, Nombre de columna: RAINNC_6_h1
# Índice: 183, Nombre de columna: RAINNC_7_h1
# Índice: 184, Nombre de columna: RAINNC_8_h1
# Índice: 185, Nombre de columna: RAINNC_9_h1
# Índice: 186, Nombre de columna: RAINNC_10_h1
# Índice: 187, Nombre de columna: RAINNC_11_h1
# Índice: 188, Nombre de columna: RAINNC_12_h1
# Índice: 189, Nombre de columna: RAINNC_13_h1
# Índice: 190, Nombre de columna: RAINNC_14_h1
# Índice: 191, Nombre de columna: RAINNC_15_h1
# Índice: 192, Nombre de columna: SWDOWN_0_h1
# Índice: 193, Nombre de columna: SWDOWN_1_h1
# Índice: 194, Nombre de columna: SWDOWN_2_h1
# Índice: 195, Nombre de columna: SWDOWN_3_h1
# Índice: 196, Nombre de columna: SWDOWN_4_h1
# Índice: 197, Nombre de columna: SWDOWN_5_h1
# Índice: 198, Nombre de columna: SWDOWN_6_h1
# Índice: 199, Nombre de columna: SWDOWN_7_h1
# Índice: 200, Nombre de columna: SWDOWN_8_h1
# Índice: 201, Nombre de columna: SWDOWN_9_h1
# Índice: 202, Nombre de columna: SWDOWN_10_h1
# Índice: 203, Nombre de columna: SWDOWN_11_h1
# Índice: 204, Nombre de columna: SWDOWN_12_h1
# Índice: 205, Nombre de columna: SWDOWN_13_h1
# Índice: 206, Nombre de columna: SWDOWN_14_h1
# Índice: 207, Nombre de columna: SWDOWN_15_h1
# Índice: 208, Nombre de columna: GLW_0_h1
# Índice: 209, Nombre de columna: GLW_1_h1
# Índice: 210, Nombre de columna: GLW_2_h1
# Índice: 211, Nombre de columna: GLW_3_h1
# Índice: 212, Nombre de columna: GLW_4_h1
# Índice: 213, Nombre de columna: GLW_5_h1
# Índice: 214, Nombre de columna: GLW_6_h1
# Índice: 215, Nombre de columna: GLW_7_h1
# Índice: 216, Nombre de columna: GLW_8_h1
# Índice: 217, Nombre de columna: GLW_9_h1
# Índice: 218, Nombre de columna: GLW_10_h1
# Índice: 219, Nombre de columna: GLW_11_h1
# Índice: 220, Nombre de columna: GLW_12_h1
# Índice: 221, Nombre de columna: GLW_13_h1
# Índice: 222, Nombre de columna: GLW_14_h1
# Índice: 223, Nombre de columna: GLW_15_h1
# Índice: 224, Nombre de columna: U10_0_h2
# Índice: 225, Nombre de columna: U10_1_h2
# Índice: 226, Nombre de columna: U10_2_h2
# Índice: 227, Nombre de columna: U10_3_h2
# Índice: 228, Nombre de columna: U10_4_h2
# Índice: 229, Nombre de columna: U10_5_h2
# Índice: 230, Nombre de columna: U10_6_h2
# Índice: 231, Nombre de columna: U10_7_h2
# Índice: 232, Nombre de columna: U10_8_h2
# Índice: 233, Nombre de columna: U10_9_h2
# Índice: 234, Nombre de columna: U10_10_h2
# Índice: 235, Nombre de columna: U10_11_h2
# Índice: 236, Nombre de columna: U10_12_h2
# Índice: 237, Nombre de columna: U10_13_h2
# Índice: 238, Nombre de columna: U10_14_h2
# Índice: 239, Nombre de columna: U10_15_h2
# Índice: 240, Nombre de columna: V10_0_h2
# Índice: 241, Nombre de columna: V10_1_h2
# Índice: 242, Nombre de columna: V10_2_h2
# Índice: 243, Nombre de columna: V10_3_h2
# Índice: 244, Nombre de columna: V10_4_h2
# Índice: 245, Nombre de columna: V10_5_h2
# Índice: 246, Nombre de columna: V10_6_h2
# Índice: 247, Nombre de columna: V10_7_h2
# Índice: 248, Nombre de columna: V10_8_h2
# Índice: 249, Nombre de columna: V10_9_h2
# Índice: 250, Nombre de columna: V10_10_h2
# Índice: 251, Nombre de columna: V10_11_h2
# Índice: 252, Nombre de columna: V10_12_h2
# Índice: 253, Nombre de columna: V10_13_h2
# Índice: 254, Nombre de columna: V10_14_h2
# Índice: 255, Nombre de columna: V10_15_h2
# Índice: 256, Nombre de columna: RAINC_0_h2
# Índice: 257, Nombre de columna: RAINC_1_h2
# Índice: 258, Nombre de columna: RAINC_2_h2
# Índice: 259, Nombre de columna: RAINC_3_h2
# Índice: 260, Nombre de columna: RAINC_4_h2
# Índice: 261, Nombre de columna: RAINC_5_h2
# Índice: 262, Nombre de columna: RAINC_6_h2
# Índice: 263, Nombre de columna: RAINC_7_h2
# Índice: 264, Nombre de columna: RAINC_8_h2
# Índice: 265, Nombre de columna: RAINC_9_h2
# Índice: 266, Nombre de columna: RAINC_10_h2
# Índice: 267, Nombre de columna: RAINC_11_h2
# Índice: 268, Nombre de columna: RAINC_12_h2
# Índice: 269, Nombre de columna: RAINC_13_h2
# Índice: 270, Nombre de columna: RAINC_14_h2
# Índice: 271, Nombre de columna: RAINC_15_h2
# Índice: 272, Nombre de columna: T2_0_h2
# Índice: 273, Nombre de columna: T2_1_h2
# Índice: 274, Nombre de columna: T2_2_h2
# Índice: 275, Nombre de columna: T2_3_h2
# Índice: 276, Nombre de columna: T2_4_h2
# Índice: 277, Nombre de columna: T2_5_h2
# Índice: 278, Nombre de columna: T2_6_h2
# Índice: 279, Nombre de columna: T2_7_h2
# Índice: 280, Nombre de columna: T2_8_h2
# Índice: 281, Nombre de columna: T2_9_h2
# Índice: 282, Nombre de columna: T2_10_h2
# Índice: 283, Nombre de columna: T2_11_h2
# Índice: 284, Nombre de columna: T2_12_h2
# Índice: 285, Nombre de columna: T2_13_h2
# Índice: 286, Nombre de columna: T2_14_h2
# Índice: 287, Nombre de columna: T2_15_h2
# Índice: 288, Nombre de columna: RAINNC_0_h2
# Índice: 289, Nombre de columna: RAINNC_1_h2
# Índice: 290, Nombre de columna: RAINNC_2_h2
# Índice: 291, Nombre de columna: RAINNC_3_h2
# Índice: 292, Nombre de columna: RAINNC_4_h2
# Índice: 293, Nombre de columna: RAINNC_5_h2
# Índice: 294, Nombre de columna: RAINNC_6_h2
# Índice: 295, Nombre de columna: RAINNC_7_h2
# Índice: 296, Nombre de columna: RAINNC_8_h2
# Índice: 297, Nombre de columna: RAINNC_9_h2
# Índice: 298, Nombre de columna: RAINNC_10_h2
# Índice: 299, Nombre de columna: RAINNC_11_h2
# Índice: 300, Nombre de columna: RAINNC_12_h2
# Índice: 301, Nombre de columna: RAINNC_13_h2
# Índice: 302, Nombre de columna: RAINNC_14_h2
# Índice: 303, Nombre de columna: RAINNC_15_h2
# Índice: 304, Nombre de columna: SWDOWN_0_h2
# Índice: 305, Nombre de columna: SWDOWN_1_h2
# Índice: 306, Nombre de columna: SWDOWN_2_h2
# Índice: 307, Nombre de columna: SWDOWN_3_h2
# Índice: 308, Nombre de columna: SWDOWN_4_h2
# Índice: 309, Nombre de columna: SWDOWN_5_h2
# Índice: 310, Nombre de columna: SWDOWN_6_h2
# Índice: 311, Nombre de columna: SWDOWN_7_h2
# Índice: 312, Nombre de columna: SWDOWN_8_h2
# Índice: 313, Nombre de columna: SWDOWN_9_h2
# Índice: 314, Nombre de columna: SWDOWN_10_h2
# Índice: 315, Nombre de columna: SWDOWN_11_h2
# Índice: 316, Nombre de columna: SWDOWN_12_h2
# Índice: 317, Nombre de columna: SWDOWN_13_h2
# Índice: 318, Nombre de columna: SWDOWN_14_h2
# Índice: 319, Nombre de columna: SWDOWN_15_h2
# Índice: 320, Nombre de columna: GLW_0_h2
# Índice: 321, Nombre de columna: GLW_1_h2
# Índice: 322, Nombre de columna: GLW_2_h2
# Índice: 323, Nombre de columna: GLW_3_h2
# Índice: 324, Nombre de columna: GLW_4_h2
# Índice: 325, Nombre de columna: GLW_5_h2
# Índice: 326, Nombre de columna: GLW_6_h2
# Índice: 327, Nombre de columna: GLW_7_h2
# Índice: 328, Nombre de columna: GLW_8_h2
# Índice: 329, Nombre de columna: GLW_9_h2
# Índice: 330, Nombre de columna: GLW_10_h2
# Índice: 331, Nombre de columna: GLW_11_h2
# Índice: 332, Nombre de columna: GLW_12_h2
# Índice: 333, Nombre de columna: GLW_13_h2
# Índice: 334, Nombre de columna: GLW_14_h2
# Índice: 335, Nombre de columna: GLW_15_h2
# Índice: 336, Nombre de columna: U10_0_h3
# Índice: 337, Nombre de columna: U10_1_h3
# Índice: 338, Nombre de columna: U10_2_h3
# Índice: 339, Nombre de columna: U10_3_h3
# Índice: 340, Nombre de columna: U10_4_h3
# Índice: 341, Nombre de columna: U10_5_h3
# Índice: 342, Nombre de columna: U10_6_h3
# Índice: 343, Nombre de columna: U10_7_h3
# Índice: 344, Nombre de columna: U10_8_h3
# Índice: 345, Nombre de columna: U10_9_h3
# Índice: 346, Nombre de columna: U10_10_h3
# Índice: 347, Nombre de columna: U10_11_h3
# Índice: 348, Nombre de columna: U10_12_h3
# Índice: 349, Nombre de columna: U10_13_h3
# Índice: 350, Nombre de columna: U10_14_h3
# Índice: 351, Nombre de columna: U10_15_h3
# Índice: 352, Nombre de columna: V10_0_h3
# Índice: 353, Nombre de columna: V10_1_h3
# Índice: 354, Nombre de columna: V10_2_h3
# Índice: 355, Nombre de columna: V10_3_h3
# Índice: 356, Nombre de columna: V10_4_h3
# Índice: 357, Nombre de columna: V10_5_h3
# Índice: 358, Nombre de columna: V10_6_h3
# Índice: 359, Nombre de columna: V10_7_h3
# Índice: 360, Nombre de columna: V10_8_h3
# Índice: 361, Nombre de columna: V10_9_h3
# Índice: 362, Nombre de columna: V10_10_h3
# Índice: 363, Nombre de columna: V10_11_h3
# Índice: 364, Nombre de columna: V10_12_h3
# Índice: 365, Nombre de columna: V10_13_h3
# Índice: 366, Nombre de columna: V10_14_h3
# Índice: 367, Nombre de columna: V10_15_h3
# Índice: 368, Nombre de columna: RAINC_0_h3
# Índice: 369, Nombre de columna: RAINC_1_h3
# Índice: 370, Nombre de columna: RAINC_2_h3
# Índice: 371, Nombre de columna: RAINC_3_h3
# Índice: 372, Nombre de columna: RAINC_4_h3
# Índice: 373, Nombre de columna: RAINC_5_h3
# Índice: 374, Nombre de columna: RAINC_6_h3
# Índice: 375, Nombre de columna: RAINC_7_h3
# Índice: 376, Nombre de columna: RAINC_8_h3
# Índice: 377, Nombre de columna: RAINC_9_h3
# Índice: 378, Nombre de columna: RAINC_10_h3
# Índice: 379, Nombre de columna: RAINC_11_h3
# Índice: 380, Nombre de columna: RAINC_12_h3
# Índice: 381, Nombre de columna: RAINC_13_h3
# Índice: 382, Nombre de columna: RAINC_14_h3
# Índice: 383, Nombre de columna: RAINC_15_h3
# Índice: 384, Nombre de columna: T2_0_h3
# Índice: 385, Nombre de columna: T2_1_h3
# Índice: 386, Nombre de columna: T2_2_h3
# Índice: 387, Nombre de columna: T2_3_h3
# Índice: 388, Nombre de columna: T2_4_h3
# Índice: 389, Nombre de columna: T2_5_h3
# Índice: 390, Nombre de columna: T2_6_h3
# Índice: 391, Nombre de columna: T2_7_h3
# Índice: 392, Nombre de columna: T2_8_h3
# Índice: 393, Nombre de columna: T2_9_h3
# Índice: 394, Nombre de columna: T2_10_h3
# Índice: 395, Nombre de columna: T2_11_h3
# Índice: 396, Nombre de columna: T2_12_h3
# Índice: 397, Nombre de columna: T2_13_h3
# Índice: 398, Nombre de columna: T2_14_h3
# Índice: 399, Nombre de columna: T2_15_h3
# Índice: 400, Nombre de columna: RAINNC_0_h3
# Índice: 401, Nombre de columna: RAINNC_1_h3
# Índice: 402, Nombre de columna: RAINNC_2_h3
# Índice: 403, Nombre de columna: RAINNC_3_h3
# Índice: 404, Nombre de columna: RAINNC_4_h3
# Índice: 405, Nombre de columna: RAINNC_5_h3
# Índice: 406, Nombre de columna: RAINNC_6_h3
# Índice: 407, Nombre de columna: RAINNC_7_h3
# Índice: 408, Nombre de columna: RAINNC_8_h3
# Índice: 409, Nombre de columna: RAINNC_9_h3
# Índice: 410, Nombre de columna: RAINNC_10_h3
# Índice: 411, Nombre de columna: RAINNC_11_h3
# Índice: 412, Nombre de columna: RAINNC_12_h3
# Índice: 413, Nombre de columna: RAINNC_13_h3
# Índice: 414, Nombre de columna: RAINNC_14_h3
# Índice: 415, Nombre de columna: RAINNC_15_h3
# Índice: 416, Nombre de columna: SWDOWN_0_h3
# Índice: 417, Nombre de columna: SWDOWN_1_h3
# Índice: 418, Nombre de columna: SWDOWN_2_h3
# Índice: 419, Nombre de columna: SWDOWN_3_h3
# Índice: 420, Nombre de columna: SWDOWN_4_h3
# Índice: 421, Nombre de columna: SWDOWN_5_h3
# Índice: 422, Nombre de columna: SWDOWN_6_h3
# Índice: 423, Nombre de columna: SWDOWN_7_h3
# Índice: 424, Nombre de columna: SWDOWN_8_h3
# Índice: 425, Nombre de columna: SWDOWN_9_h3
# Índice: 426, Nombre de columna: SWDOWN_10_h3
# Índice: 427, Nombre de columna: SWDOWN_11_h3
# Índice: 428, Nombre de columna: SWDOWN_12_h3
# Índice: 429, Nombre de columna: SWDOWN_13_h3
# Índice: 430, Nombre de columna: SWDOWN_14_h3
# Índice: 431, Nombre de columna: SWDOWN_15_h3
# Índice: 432, Nombre de columna: GLW_0_h3
# Índice: 433, Nombre de columna: GLW_1_h3
# Índice: 434, Nombre de columna: GLW_2_h3
# Índice: 435, Nombre de columna: GLW_3_h3
# Índice: 436, Nombre de columna: GLW_4_h3
# Índice: 437, Nombre de columna: GLW_5_h3
# Índice: 438, Nombre de columna: GLW_6_h3
# Índice: 439, Nombre de columna: GLW_7_h3
# Índice: 440, Nombre de columna: GLW_8_h3
# Índice: 441, Nombre de columna: GLW_9_h3
# Índice: 442, Nombre de columna: GLW_10_h3
# Índice: 443, Nombre de columna: GLW_11_h3
# Índice: 444, Nombre de columna: GLW_12_h3
# Índice: 445, Nombre de columna: GLW_13_h3
# Índice: 446, Nombre de columna: GLW_14_h3
# Índice: 447, Nombre de columna: GLW_15_h3
# Índice: 448, Nombre de columna: U10_0_h4
# Índice: 449, Nombre de columna: U10_1_h4
# Índice: 450, Nombre de columna: U10_2_h4
# Índice: 451, Nombre de columna: U10_3_h4
# Índice: 452, Nombre de columna: U10_4_h4
# Índice: 453, Nombre de columna: U10_5_h4
# Índice: 454, Nombre de columna: U10_6_h4
# Índice: 455, Nombre de columna: U10_7_h4
# Índice: 456, Nombre de columna: U10_8_h4
# Índice: 457, Nombre de columna: U10_9_h4
# Índice: 458, Nombre de columna: U10_10_h4
# Índice: 459, Nombre de columna: U10_11_h4
# Índice: 460, Nombre de columna: U10_12_h4
# Índice: 461, Nombre de columna: U10_13_h4
# Índice: 462, Nombre de columna: U10_14_h4
# Índice: 463, Nombre de columna: U10_15_h4
# Índice: 464, Nombre de columna: V10_0_h4
# Índice: 465, Nombre de columna: V10_1_h4
# Índice: 466, Nombre de columna: V10_2_h4
# Índice: 467, Nombre de columna: V10_3_h4
# Índice: 468, Nombre de columna: V10_4_h4
# Índice: 469, Nombre de columna: V10_5_h4
# Índice: 470, Nombre de columna: V10_6_h4
# Índice: 471, Nombre de columna: V10_7_h4
# Índice: 472, Nombre de columna: V10_8_h4
# Índice: 473, Nombre de columna: V10_9_h4
# Índice: 474, Nombre de columna: V10_10_h4
# Índice: 475, Nombre de columna: V10_11_h4
# Índice: 476, Nombre de columna: V10_12_h4
# Índice: 477, Nombre de columna: V10_13_h4
# Índice: 478, Nombre de columna: V10_14_h4
# Índice: 479, Nombre de columna: V10_15_h4
# Índice: 480, Nombre de columna: RAINC_0_h4
# Índice: 481, Nombre de columna: RAINC_1_h4
# Índice: 482, Nombre de columna: RAINC_2_h4
# Índice: 483, Nombre de columna: RAINC_3_h4
# Índice: 484, Nombre de columna: RAINC_4_h4
# Índice: 485, Nombre de columna: RAINC_5_h4
# Índice: 486, Nombre de columna: RAINC_6_h4
# Índice: 487, Nombre de columna: RAINC_7_h4
# Índice: 488, Nombre de columna: RAINC_8_h4
# Índice: 489, Nombre de columna: RAINC_9_h4
# Índice: 490, Nombre de columna: RAINC_10_h4
# Índice: 491, Nombre de columna: RAINC_11_h4
# Índice: 492, Nombre de columna: RAINC_12_h4
# Índice: 493, Nombre de columna: RAINC_13_h4
# Índice: 494, Nombre de columna: RAINC_14_h4
# Índice: 495, Nombre de columna: RAINC_15_h4
# Índice: 496, Nombre de columna: T2_0_h4
# Índice: 497, Nombre de columna: T2_1_h4
# Índice: 498, Nombre de columna: T2_2_h4
# Índice: 499, Nombre de columna: T2_3_h4
# Índice: 500, Nombre de columna: T2_4_h4
# Índice: 501, Nombre de columna: T2_5_h4
# Índice: 502, Nombre de columna: T2_6_h4
# Índice: 503, Nombre de columna: T2_7_h4
# Índice: 504, Nombre de columna: T2_8_h4
# Índice: 505, Nombre de columna: T2_9_h4
# Índice: 506, Nombre de columna: T2_10_h4
# Índice: 507, Nombre de columna: T2_11_h4
# Índice: 508, Nombre de columna: T2_12_h4
# Índice: 509, Nombre de columna: T2_13_h4
# Índice: 510, Nombre de columna: T2_14_h4
# Índice: 511, Nombre de columna: T2_15_h4
# Índice: 512, Nombre de columna: RAINNC_0_h4
# Índice: 513, Nombre de columna: RAINNC_1_h4
# Índice: 514, Nombre de columna: RAINNC_2_h4
# Índice: 515, Nombre de columna: RAINNC_3_h4
# Índice: 516, Nombre de columna: RAINNC_4_h4
# Índice: 517, Nombre de columna: RAINNC_5_h4
# Índice: 518, Nombre de columna: RAINNC_6_h4
# Índice: 519, Nombre de columna: RAINNC_7_h4
# Índice: 520, Nombre de columna: RAINNC_8_h4
# Índice: 521, Nombre de columna: RAINNC_9_h4
# Índice: 522, Nombre de columna: RAINNC_10_h4
# Índice: 523, Nombre de columna: RAINNC_11_h4
# Índice: 524, Nombre de columna: RAINNC_12_h4
# Índice: 525, Nombre de columna: RAINNC_13_h4
# Índice: 526, Nombre de columna: RAINNC_14_h4
# Índice: 527, Nombre de columna: RAINNC_15_h4
# Índice: 528, Nombre de columna: SWDOWN_0_h4
# Índice: 529, Nombre de columna: SWDOWN_1_h4
# Índice: 530, Nombre de columna: SWDOWN_2_h4
# Índice: 531, Nombre de columna: SWDOWN_3_h4
# Índice: 532, Nombre de columna: SWDOWN_4_h4
# Índice: 533, Nombre de columna: SWDOWN_5_h4
# Índice: 534, Nombre de columna: SWDOWN_6_h4
# Índice: 535, Nombre de columna: SWDOWN_7_h4
# Índice: 536, Nombre de columna: SWDOWN_8_h4
# Índice: 537, Nombre de columna: SWDOWN_9_h4
# Índice: 538, Nombre de columna: SWDOWN_10_h4
# Índice: 539, Nombre de columna: SWDOWN_11_h4
# Índice: 540, Nombre de columna: SWDOWN_12_h4
# Índice: 541, Nombre de columna: SWDOWN_13_h4
# Índice: 542, Nombre de columna: SWDOWN_14_h4
# Índice: 543, Nombre de columna: SWDOWN_15_h4
# Índice: 544, Nombre de columna: GLW_0_h4
# Índice: 545, Nombre de columna: GLW_1_h4
# Índice: 546, Nombre de columna: GLW_2_h4
# Índice: 547, Nombre de columna: GLW_3_h4
# Índice: 548, Nombre de columna: GLW_4_h4
# Índice: 549, Nombre de columna: GLW_5_h4
# Índice: 550, Nombre de columna: GLW_6_h4
# Índice: 551, Nombre de columna: GLW_7_h4
# Índice: 552, Nombre de columna: GLW_8_h4
# Índice: 553, Nombre de columna: GLW_9_h4
# Índice: 554, Nombre de columna: GLW_10_h4
# Índice: 555, Nombre de columna: GLW_11_h4
# Índice: 556, Nombre de columna: GLW_12_h4
# Índice: 557, Nombre de columna: GLW_13_h4
# Índice: 558, Nombre de columna: GLW_14_h4
# Índice: 559, Nombre de columna: GLW_15_h4
# Índice: 560, Nombre de columna: U10_0_h5
# Índice: 561, Nombre de columna: U10_1_h5
# Índice: 562, Nombre de columna: U10_2_h5
# Índice: 563, Nombre de columna: U10_3_h5
# Índice: 564, Nombre de columna: U10_4_h5
# Índice: 565, Nombre de columna: U10_5_h5
# Índice: 566, Nombre de columna: U10_6_h5
# Índice: 567, Nombre de columna: U10_7_h5
# Índice: 568, Nombre de columna: U10_8_h5
# Índice: 569, Nombre de columna: U10_9_h5
# Índice: 570, Nombre de columna: U10_10_h5
# Índice: 571, Nombre de columna: U10_11_h5
# Índice: 572, Nombre de columna: U10_12_h5
# Índice: 573, Nombre de columna: U10_13_h5
# Índice: 574, Nombre de columna: U10_14_h5
# Índice: 575, Nombre de columna: U10_15_h5
# Índice: 576, Nombre de columna: V10_0_h5
# Índice: 577, Nombre de columna: V10_1_h5
# Índice: 578, Nombre de columna: V10_2_h5
# Índice: 579, Nombre de columna: V10_3_h5
# Índice: 580, Nombre de columna: V10_4_h5
# Índice: 581, Nombre de columna: V10_5_h5
# Índice: 642, Nombre de columna: SWDOWN_2_h5
# Índice: 643, Nombre de columna: SWDOWN_3_h5
# Índice: 644, Nombre de columna: SWDOWN_4_h5
# Índice: 645, Nombre de columna: SWDOWN_5_h5
# Índice: 646, Nombre de columna: SWDOWN_6_h5
# Índice: 647, Nombre de columna: SWDOWN_7_h5
# Índice: 648, Nombre de columna: SWDOWN_8_h5
# Índice: 649, Nombre de columna: SWDOWN_9_h5
# Índice: 650, Nombre de columna: SWDOWN_10_h5
# Índice: 651, Nombre de columna: SWDOWN_11_h5
# Índice: 652, Nombre de columna: SWDOWN_12_h5
# Índice: 653, Nombre de columna: SWDOWN_13_h5
# Índice: 654, Nombre de columna: SWDOWN_14_h5
# Índice: 655, Nombre de columna: SWDOWN_15_h5
# Índice: 656, Nombre de columna: GLW_0_h5
# Índice: 657, Nombre de columna: GLW_1_h5
# Índice: 658, Nombre de columna: GLW_2_h5
# Índice: 659, Nombre de columna: GLW_3_h5
# Índice: 660, Nombre de columna: GLW_4_h5
# Índice: 661, Nombre de columna: GLW_5_h5
# Índice: 662, Nombre de columna: GLW_6_h5
# Índice: 663, Nombre de columna: GLW_7_h5
# Índice: 664, Nombre de columna: GLW_8_h5
# Índice: 665, Nombre de columna: GLW_9_h5
# Índice: 666, Nombre de columna: GLW_10_h5
# Índice: 667, Nombre de columna: GLW_11_h5
# Índice: 668, Nombre de columna: GLW_12_h5
# Índice: 669, Nombre de columna: GLW_13_h5
# Índice: 670, Nombre de columna: GLW_14_h5
# Índice: 671, Nombre de columna: GLW_15_h5
# Índice: 672, Nombre de columna: U10_0_h6
# Índice: 673, Nombre de columna: U10_1_h6
# Índice: 674, Nombre de columna: U10_2_h6
# Índice: 675, Nombre de columna: U10_3_h6
# Índice: 676, Nombre de columna: U10_4_h6
# Índice: 677, Nombre de columna: U10_5_h6
# Índice: 678, Nombre de columna: U10_6_h6
# Índice: 679, Nombre de columna: U10_7_h6
# Índice: 680, Nombre de columna: U10_8_h6
# Índice: 681, Nombre de columna: U10_9_h6
# Índice: 682, Nombre de columna: U10_10_h6
# Índice: 683, Nombre de columna: U10_11_h6
# Índice: 684, Nombre de columna: U10_12_h6
# Índice: 685, Nombre de columna: U10_13_h6
# Índice: 686, Nombre de columna: U10_14_h6
# Índice: 687, Nombre de columna: U10_15_h6
# Índice: 688, Nombre de columna: V10_0_h6
# Índice: 689, Nombre de columna: V10_1_h6
# Índice: 690, Nombre de columna: V10_2_h6
# Índice: 691, Nombre de columna: V10_3_h6
# Índice: 692, Nombre de columna: V10_4_h6
# Índice: 693, Nombre de columna: V10_5_h6
# Índice: 694, Nombre de columna: V10_6_h6
# Índice: 695, Nombre de columna: V10_7_h6
# Índice: 696, Nombre de columna: V10_8_h6
# Índice: 697, Nombre de columna: V10_9_h6
# Índice: 698, Nombre de columna: V10_10_h6
# Índice: 699, Nombre de columna: V10_11_h6
# Índice: 700, Nombre de columna: V10_12_h6
# Índice: 701, Nombre de columna: V10_13_h6
# Índice: 702, Nombre de columna: V10_14_h6
# Índice: 703, Nombre de columna: V10_15_h6
# Índice: 704, Nombre de columna: RAINC_0_h6
# Índice: 705, Nombre de columna: RAINC_1_h6
# Índice: 706, Nombre de columna: RAINC_2_h6
# Índice: 707, Nombre de columna: RAINC_3_h6
# Índice: 708, Nombre de columna: RAINC_4_h6
# Índice: 709, Nombre de columna: RAINC_5_h6
# Índice: 710, Nombre de columna: RAINC_6_h6
# Índice: 711, Nombre de columna: RAINC_7_h6
# Índice: 712, Nombre de columna: RAINC_8_h6
# Índice: 713, Nombre de columna: RAINC_9_h6
# Índice: 714, Nombre de columna: RAINC_10_h6
# Índice: 715, Nombre de columna: RAINC_11_h6
# Índice: 716, Nombre de columna: RAINC_12_h6
# Índice: 717, Nombre de columna: RAINC_13_h6
# Índice: 718, Nombre de columna: RAINC_14_h6
# Índice: 719, Nombre de columna: RAINC_15_h6
# Índice: 720, Nombre de columna: T2_0_h6
# Índice: 721, Nombre de columna: T2_1_h6
# Índice: 722, Nombre de columna: T2_2_h6
# Índice: 723, Nombre de columna: T2_3_h6
# Índice: 724, Nombre de columna: T2_4_h6
# Índice: 725, Nombre de columna: T2_5_h6
# Índice: 726, Nombre de columna: T2_6_h6
# Índice: 727, Nombre de columna: T2_7_h6
# Índice: 728, Nombre de columna: T2_8_h6
# Índice: 729, Nombre de columna: T2_9_h6
# Índice: 730, Nombre de columna: T2_10_h6
# Índice: 731, Nombre de columna: T2_11_h6
# Índice: 732, Nombre de columna: T2_12_h6
# Índice: 733, Nombre de columna: T2_13_h6
# Índice: 734, Nombre de columna: T2_14_h6
# Índice: 735, Nombre de columna: T2_15_h6
# Índice: 736, Nombre de columna: RAINNC_0_h6
# Índice: 737, Nombre de columna: RAINNC_1_h6
# Índice: 738, Nombre de columna: RAINNC_2_h6
# Índice: 739, Nombre de columna: RAINNC_3_h6
# Índice: 740, Nombre de columna: RAINNC_4_h6
# Índice: 741, Nombre de columna: RAINNC_5_h6
# Índice: 742, Nombre de columna: RAINNC_6_h6
# Índice: 743, Nombre de columna: RAINNC_7_h6
# Índice: 744, Nombre de columna: RAINNC_8_h6
# Índice: 745, Nombre de columna: RAINNC_9_h6
# Índice: 746, Nombre de columna: RAINNC_10_h6
# Índice: 747, Nombre de columna: RAINNC_11_h6
# Índice: 748, Nombre de columna: RAINNC_12_h6
# Índice: 749, Nombre de columna: RAINNC_13_h6
# Índice: 750, Nombre de columna: RAINNC_14_h6
# Índice: 751, Nombre de columna: RAINNC_15_h6
# Índice: 752, Nombre de columna: SWDOWN_0_h6
# Índice: 753, Nombre de columna: SWDOWN_1_h6
# Índice: 754, Nombre de columna: SWDOWN_2_h6
# Índice: 755, Nombre de columna: SWDOWN_3_h6
# Índice: 756, Nombre de columna: SWDOWN_4_h6
# Índice: 757, Nombre de columna: SWDOWN_5_h6
# Índice: 758, Nombre de columna: SWDOWN_6_h6
# Índice: 759, Nombre de columna: SWDOWN_7_h6
# Índice: 760, Nombre de columna: SWDOWN_8_h6
# Índice: 761, Nombre de columna: SWDOWN_9_h6
# Índice: 762, Nombre de columna: SWDOWN_10_h6
# Índice: 763, Nombre de columna: SWDOWN_11_h6
# Índice: 764, Nombre de columna: SWDOWN_12_h6
# Índice: 765, Nombre de columna: SWDOWN_13_h6
# Índice: 766, Nombre de columna: SWDOWN_14_h6
# Índice: 767, Nombre de columna: SWDOWN_15_h6
# Índice: 768, Nombre de columna: GLW_0_h6
# Índice: 769, Nombre de columna: GLW_1_h6
# Índice: 770, Nombre de columna: GLW_2_h6
# Índice: 771, Nombre de columna: GLW_3_h6
# Índice: 772, Nombre de columna: GLW_4_h6
# Índice: 773, Nombre de columna: GLW_5_h6
# Índice: 774, Nombre de columna: GLW_6_h6
# Índice: 775, Nombre de columna: GLW_7_h6
# Índice: 776, Nombre de columna: GLW_8_h6
# Índice: 777, Nombre de columna: GLW_9_h6
# Índice: 778, Nombre de columna: GLW_10_h6
# Índice: 779, Nombre de columna: GLW_11_h6
# Índice: 780, Nombre de columna: GLW_12_h6
# Índice: 781, Nombre de columna: GLW_13_h6
# Índice: 782, Nombre de columna: GLW_14_h6
# Índice: 783, Nombre de columna: GLW_15_h6
# Índice: 784, Nombre de columna: U10_0_h7
# Índice: 785, Nombre de columna: U10_1_h7
# Índice: 786, Nombre de columna: U10_2_h7
# Índice: 787, Nombre de columna: U10_3_h7
# Índice: 788, Nombre de columna: U10_4_h7
# Índice: 789, Nombre de columna: U10_5_h7
# Índice: 790, Nombre de columna: U10_6_h7
# Índice: 791, Nombre de columna: U10_7_h7
# Índice: 792, Nombre de columna: U10_8_h7
# Índice: 793, Nombre de columna: U10_9_h7
# Índice: 794, Nombre de columna: U10_10_h7
# Índice: 795, Nombre de columna: U10_11_h7
# Índice: 796, Nombre de columna: U10_12_h7
# Índice: 797, Nombre de columna: U10_13_h7
# Índice: 798, Nombre de columna: U10_14_h7
# Índice: 799, Nombre de columna: U10_15_h7
# Índice: 800, Nombre de columna: V10_0_h7
# Índice: 801, Nombre de columna: V10_1_h7
# Índice: 802, Nombre de columna: V10_2_h7
# Índice: 803, Nombre de columna: V10_3_h7
# Índice: 804, Nombre de columna: V10_4_h7
# Índice: 805, Nombre de columna: V10_5_h7
# Índice: 806, Nombre de columna: V10_6_h7
# Índice: 807, Nombre de columna: V10_7_h7
# Índice: 808, Nombre de columna: V10_8_h7
# Índice: 809, Nombre de columna: V10_9_h7
# Índice: 810, Nombre de columna: V10_10_h7
# Índice: 811, Nombre de columna: V10_11_h7
# Índice: 812, Nombre de columna: V10_12_h7
# Índice: 813, Nombre de columna: V10_13_h7
# Índice: 814, Nombre de columna: V10_14_h7
# Índice: 815, Nombre de columna: V10_15_h7
# Índice: 816, Nombre de columna: RAINC_0_h7
# Índice: 817, Nombre de columna: RAINC_1_h7
# Índice: 818, Nombre de columna: RAINC_2_h7
# Índice: 819, Nombre de columna: RAINC_3_h7
# Índice: 820, Nombre de columna: RAINC_4_h7
# Índice: 821, Nombre de columna: RAINC_5_h7
# Índice: 822, Nombre de columna: RAINC_6_h7
# Índice: 823, Nombre de columna: RAINC_7_h7
# Índice: 882, Nombre de columna: GLW_2_h7
# Índice: 883, Nombre de columna: GLW_3_h7
# Índice: 884, Nombre de columna: GLW_4_h7
# Índice: 885, Nombre de columna: GLW_5_h7
# Índice: 886, Nombre de columna: GLW_6_h7
# Índice: 887, Nombre de columna: GLW_7_h7
# Índice: 888, Nombre de columna: GLW_8_h7
# Índice: 889, Nombre de columna: GLW_9_h7
# Índice: 890, Nombre de columna: GLW_10_h7
# Índice: 891, Nombre de columna: GLW_11_h7
# Índice: 892, Nombre de columna: GLW_12_h7
# Índice: 893, Nombre de columna: GLW_13_h7
# Índice: 894, Nombre de columna: GLW_14_h7
# Índice: 895, Nombre de columna: GLW_15_h7
# Índice: 896, Nombre de columna: U10_0_h8
# Índice: 897, Nombre de columna: U10_1_h8
# Índice: 898, Nombre de columna: U10_2_h8
# Índice: 899, Nombre de columna: U10_3_h8
# Índice: 900, Nombre de columna: U10_4_h8
# Índice: 901, Nombre de columna: U10_5_h8
# Índice: 902, Nombre de columna: U10_6_h8
# Índice: 903, Nombre de columna: U10_7_h8
# Índice: 904, Nombre de columna: U10_8_h8
# Índice: 905, Nombre de columna: U10_9_h8
# Índice: 906, Nombre de columna: U10_10_h8
# Índice: 907, Nombre de columna: U10_11_h8
# Índice: 908, Nombre de columna: U10_12_h8
# Índice: 909, Nombre de columna: U10_13_h8
# Índice: 910, Nombre de columna: U10_14_h8
# Índice: 911, Nombre de columna: U10_15_h8
# Índice: 912, Nombre de columna: V10_0_h8
# Índice: 913, Nombre de columna: V10_1_h8
# Índice: 914, Nombre de columna: V10_2_h8
# Índice: 915, Nombre de columna: V10_3_h8
# Índice: 916, Nombre de columna: V10_4_h8
# Índice: 917, Nombre de columna: V10_5_h8
# Índice: 918, Nombre de columna: V10_6_h8
# Índice: 919, Nombre de columna: V10_7_h8
# Índice: 920, Nombre de columna: V10_8_h8
# Índice: 921, Nombre de columna: V10_9_h8
# Índice: 922, Nombre de columna: V10_10_h8
# Índice: 923, Nombre de columna: V10_11_h8
# Índice: 924, Nombre de columna: V10_12_h8
# Índice: 925, Nombre de columna: V10_13_h8
# Índice: 926, Nombre de columna: V10_14_h8
# Índice: 927, Nombre de columna: V10_15_h8
# Índice: 928, Nombre de columna: RAINC_0_h8
# Índice: 929, Nombre de columna: RAINC_1_h8
# Índice: 930, Nombre de columna: RAINC_2_h8
# Índice: 931, Nombre de columna: RAINC_3_h8
# Índice: 932, Nombre de columna: RAINC_4_h8
# Índice: 933, Nombre de columna: RAINC_5_h8
# Índice: 934, Nombre de columna: RAINC_6_h8
# Índice: 935, Nombre de columna: RAINC_7_h8
# Índice: 936, Nombre de columna: RAINC_8_h8
# Índice: 937, Nombre de columna: RAINC_9_h8
# Índice: 938, Nombre de columna: RAINC_10_h8
# Índice: 939, Nombre de columna: RAINC_11_h8
# Índice: 940, Nombre de columna: RAINC_12_h8
# Índice: 941, Nombre de columna: RAINC_13_h8
# Índice: 942, Nombre de columna: RAINC_14_h8
# Índice: 943, Nombre de columna: RAINC_15_h8
# Índice: 944, Nombre de columna: T2_0_h8
# Índice: 945, Nombre de columna: T2_1_h8
# Índice: 946, Nombre de columna: T2_2_h8
# Índice: 947, Nombre de columna: T2_3_h8
# Índice: 948, Nombre de columna: T2_4_h8
# Índice: 949, Nombre de columna: T2_5_h8
# Índice: 950, Nombre de columna: T2_6_h8
# Índice: 951, Nombre de columna: T2_7_h8
# Índice: 952, Nombre de columna: T2_8_h8
# Índice: 953, Nombre de columna: T2_9_h8
# Índice: 954, Nombre de columna: T2_10_h8
# Índice: 955, Nombre de columna: T2_11_h8
# Índice: 956, Nombre de columna: T2_12_h8
# Índice: 957, Nombre de columna: T2_13_h8
# Índice: 958, Nombre de columna: T2_14_h8
# Índice: 959, Nombre de columna: T2_15_h8
# Índice: 960, Nombre de columna: RAINNC_0_h8
# Índice: 961, Nombre de columna: RAINNC_1_h8
# Índice: 962, Nombre de columna: RAINNC_2_h8
# Índice: 963, Nombre de columna: RAINNC_3_h8
# Índice: 964, Nombre de columna: RAINNC_4_h8
# Índice: 965, Nombre de columna: RAINNC_5_h8
# Índice: 966, Nombre de columna: RAINNC_6_h8
# Índice: 967, Nombre de columna: RAINNC_7_h8
# Índice: 968, Nombre de columna: RAINNC_8_h8
# Índice: 969, Nombre de columna: RAINNC_9_h8
# Índice: 970, Nombre de columna: RAINNC_10_h8
# Índice: 971, Nombre de columna: RAINNC_11_h8
# Índice: 972, Nombre de columna: RAINNC_12_h8
# Índice: 973, Nombre de columna: RAINNC_13_h8
# Índice: 974, Nombre de columna: RAINNC_14_h8
# Índice: 975, Nombre de columna: RAINNC_15_h8
# Índice: 976, Nombre de columna: SWDOWN_0_h8
# Índice: 977, Nombre de columna: SWDOWN_1_h8
# Índice: 978, Nombre de columna: SWDOWN_2_h8
# Índice: 979, Nombre de columna: SWDOWN_3_h8
# Índice: 980, Nombre de columna: SWDOWN_4_h8
# Índice: 981, Nombre de columna: SWDOWN_5_h8
# Índice: 982, Nombre de columna: SWDOWN_6_h8
# Índice: 983, Nombre de columna: SWDOWN_7_h8
# Índice: 984, Nombre de columna: SWDOWN_8_h8
# Índice: 985, Nombre de columna: SWDOWN_9_h8
# Índice: 986, Nombre de columna: SWDOWN_10_h8
# Índice: 987, Nombre de columna: SWDOWN_11_h8
# Índice: 988, Nombre de columna: SWDOWN_12_h8
# Índice: 989, Nombre de columna: SWDOWN_13_h8
# Índice: 990, Nombre de columna: SWDOWN_14_h8
# Índice: 991, Nombre de columna: SWDOWN_15_h8
# Índice: 992, Nombre de columna: GLW_0_h8
# Índice: 993, Nombre de columna: GLW_1_h8
# Índice: 994, Nombre de columna: GLW_2_h8
# Índice: 995, Nombre de columna: GLW_3_h8
# Índice: 996, Nombre de columna: GLW_4_h8
# Índice: 997, Nombre de columna: GLW_5_h8
# Índice: 998, Nombre de columna: GLW_6_h8
# Índice: 999, Nombre de columna: GLW_7_h8
# Índice: 1000, Nombre de columna: GLW_8_h8
# Índice: 1001, Nombre de columna: GLW_9_h8
# Índice: 1002, Nombre de columna: GLW_10_h8
# Índice: 1003, Nombre de columna: GLW_11_h8
# Índice: 1004, Nombre de columna: GLW_12_h8
# Índice: 1005, Nombre de columna: GLW_13_h8
# Índice: 1006, Nombre de columna: GLW_14_h8
# Índice: 1007, Nombre de columna: GLW_15_h8
# Índice: 1008, Nombre de columna: U10_0_h9
# Índice: 1009, Nombre de columna: U10_1_h9
# Índice: 1010, Nombre de columna: U10_2_h9
# Índice: 1011, Nombre de columna: U10_3_h9
# Índice: 1012, Nombre de columna: U10_4_h9
# Índice: 1013, Nombre de columna: U10_5_h9
# Índice: 1014, Nombre de columna: U10_6_h9
# Índice: 1015, Nombre de columna: U10_7_h9
# Índice: 1016, Nombre de columna: U10_8_h9
# Índice: 1017, Nombre de columna: U10_9_h9
# Índice: 1018, Nombre de columna: U10_10_h9
# Índice: 1019, Nombre de columna: U10_11_h9
# Índice: 1020, Nombre de columna: U10_12_h9
# Índice: 1021, Nombre de columna: U10_13_h9
# Índice: 1022, Nombre de columna: U10_14_h9
# Índice: 1023, Nombre de columna: U10_15_h9
# Índice: 1024, Nombre de columna: V10_0_h9
# Índice: 1025, Nombre de columna: V10_1_h9
# Índice: 1026, Nombre de columna: V10_2_h9
# Índice: 1027, Nombre de columna: V10_3_h9
# Índice: 1028, Nombre de columna: V10_4_h9
# Índice: 1029, Nombre de columna: V10_5_h9
# Índice: 1030, Nombre de columna: V10_6_h9
# Índice: 1031, Nombre de columna: V10_7_h9
# Índice: 1032, Nombre de columna: V10_8_h9
# Índice: 1033, Nombre de columna: V10_9_h9
# Índice: 1034, Nombre de columna: V10_10_h9
# Índice: 1035, Nombre de columna: V10_11_h9
# Índice: 1036, Nombre de columna: V10_12_h9
# Índice: 1037, Nombre de columna: V10_13_h9
# Índice: 1038, Nombre de columna: V10_14_h9
# Índice: 1039, Nombre de columna: V10_15_h9
# Índice: 1040, Nombre de columna: RAINC_0_h9
# Índice: 1041, Nombre de columna: RAINC_1_h9
# Índice: 1042, Nombre de columna: RAINC_2_h9
# Índice: 1043, Nombre de columna: RAINC_3_h9
# Índice: 1044, Nombre de columna: RAINC_4_h9
# Índice: 1045, Nombre de columna: RAINC_5_h9
# Índice: 1046, Nombre de columna: RAINC_6_h9
# Índice: 1047, Nombre de columna: RAINC_7_h9
# Índice: 1048, Nombre de columna: RAINC_8_h9
# Índice: 1049, Nombre de columna: RAINC_9_h9
# Índice: 1050, Nombre de columna: RAINC_10_h9
# Índice: 1051, Nombre de columna: RAINC_11_h9
# Índice: 1052, Nombre de columna: RAINC_12_h9
# Índice: 1053, Nombre de columna: RAINC_13_h9
# Índice: 1054, Nombre de columna: RAINC_14_h9
# Índice: 1055, Nombre de columna: RAINC_15_h9
# Índice: 1056, Nombre de columna: T2_0_h9
# Índice: 1057, Nombre de columna: T2_1_h9
# Índice: 1058, Nombre de columna: T2_2_h9
# Índice: 1059, Nombre de columna: T2_3_h9
# Índice: 1060, Nombre de columna: T2_4_h9
# Índice: 1061, Nombre de columna: T2_5_h9
# Índice: 1062, Nombre de columna: T2_6_h9
# Índice: 1063, Nombre de columna: T2_7_h9
# Índice: 1064, Nombre de columna: T2_8_h9
# Índice: 1065, Nombre de columna: T2_9_h9
# Índice: 1066, Nombre de columna: T2_10_h9
# Índice: 1067, Nombre de columna: T2_11_h9
# Índice: 1068, Nombre de columna: T2_12_h9
# Índice: 1069, Nombre de columna: T2_13_h9
# Índice: 1070, Nombre de columna: T2_14_h9
# Índice: 1071, Nombre de columna: T2_15_h9
# Índice: 1072, Nombre de columna: RAINNC_0_h9
# Índice: 1073, Nombre de columna: RAINNC_1_h9
# Índice: 1074, Nombre de columna: RAINNC_2_h9
# Índice: 1075, Nombre de columna: RAINNC_3_h9
# Índice: 1076, Nombre de columna: RAINNC_4_h9
# Índice: 1077, Nombre de columna: RAINNC_5_h9
# Índice: 1078, Nombre de columna: RAINNC_6_h9
# Índice: 1079, Nombre de columna: RAINNC_7_h9
# Índice: 1080, Nombre de columna: RAINNC_8_h9
# Índice: 1081, Nombre de columna: RAINNC_9_h9
# Índice: 1082, Nombre de columna: RAINNC_10_h9
# Índice: 1083, Nombre de columna: RAINNC_11_h9
# Índice: 1084, Nombre de columna: RAINNC_12_h9
# Índice: 1085, Nombre de columna: RAINNC_13_h9
# Índice: 1086, Nombre de columna: RAINNC_14_h9
# Índice: 1087, Nombre de columna: RAINNC_15_h9
# Índice: 1088, Nombre de columna: SWDOWN_0_h9
# Índice: 1089, Nombre de columna: SWDOWN_1_h9
# Índice: 1090, Nombre de columna: SWDOWN_2_h9
# Índice: 1091, Nombre de columna: SWDOWN_3_h9
# Índice: 1092, Nombre de columna: SWDOWN_4_h9
# Índice: 1093, Nombre de columna: SWDOWN_5_h9
# Índice: 1094, Nombre de columna: SWDOWN_6_h9
# Índice: 1095, Nombre de columna: SWDOWN_7_h9
# Índice: 1096, Nombre de columna: SWDOWN_8_h9
# Índice: 1097, Nombre de columna: SWDOWN_9_h9
# Índice: 1098, Nombre de columna: SWDOWN_10_h9
# Índice: 1099, Nombre de columna: SWDOWN_11_h9
# Índice: 1100, Nombre de columna: SWDOWN_12_h9
# Índice: 1101, Nombre de columna: SWDOWN_13_h9
# Índice: 1102, Nombre de columna: SWDOWN_14_h9
# Índice: 1103, Nombre de columna: SWDOWN_15_h9
# Índice: 1104, Nombre de columna: GLW_0_h9
# Índice: 1105, Nombre de columna: GLW_1_h9
# Índice: 1106, Nombre de columna: GLW_2_h9
# Índice: 1107, Nombre de columna: GLW_3_h9
# Índice: 1108, Nombre de columna: GLW_4_h9
# Índice: 1109, Nombre de columna: GLW_5_h9
# Índice: 1110, Nombre de columna: GLW_6_h9
# Índice: 1111, Nombre de columna: GLW_7_h9
# Índice: 1112, Nombre de columna: GLW_8_h9
# Índice: 1113, Nombre de columna: GLW_9_h9
# Índice: 1114, Nombre de columna: GLW_10_h9
# Índice: 1115, Nombre de columna: GLW_11_h9
# Índice: 1116, Nombre de columna: GLW_12_h9
# Índice: 1117, Nombre de columna: GLW_13_h9
# Índice: 1118, Nombre de columna: GLW_14_h9
# Índice: 1119, Nombre de columna: GLW_15_h9
# Índice: 1120, Nombre de columna: U10_0_h10
# Índice: 1121, Nombre de columna: U10_1_h10
# Índice: 1122, Nombre de columna: U10_2_h10
# Índice: 1123, Nombre de columna: U10_3_h10
# Índice: 1124, Nombre de columna: U10_4_h10
# Índice: 1125, Nombre de columna: U10_5_h10
# Índice: 1126, Nombre de columna: U10_6_h10
# Índice: 1127, Nombre de columna: U10_7_h10
# Índice: 1128, Nombre de columna: U10_8_h10
# Índice: 1129, Nombre de columna: U10_9_h10
# Índice: 1130, Nombre de columna: U10_10_h10
# Índice: 1131, Nombre de columna: U10_11_h10
# ...
# Índice: 2390, Nombre de columna: RAINC_6_h21
# Índice: 2391, Nombre de columna: RAINC_7_h21
# Índice: 2392, Nombre de columna: RAINC_8_h21
# Índice: 2393, Nombre de columna: RAINC_9_h21
# Índice: 2394, Nombre de columna: RAINC_10_h21
# Índice: 2395, Nombre de columna: RAINC_11_h21
# Índice: 2396, Nombre de columna: RAINC_12_h21
# Índice: 2397, Nombre de columna: RAINC_13_h21
# Índice: 2398, Nombre de columna: RAINC_14_h21
# Índice: 2399, Nombre de columna: RAINC_15_h21
# Índice: 2400, Nombre de columna: T2_0_h21
# Índice: 2401, Nombre de columna: T2_1_h21
# Índice: 2402, Nombre de columna: T2_2_h21
# Índice: 2403, Nombre de columna: T2_3_h21
# Índice: 2404, Nombre de columna: T2_4_h21
# Índice: 2405, Nombre de columna: T2_5_h21
# Índice: 2406, Nombre de columna: T2_6_h21
# Índice: 2407, Nombre de columna: T2_7_h21
# Índice: 2408, Nombre de columna: T2_8_h21
# Índice: 2409, Nombre de columna: T2_9_h21
# Índice: 2410, Nombre de columna: T2_10_h21
# Índice: 2411, Nombre de columna: T2_11_h21
# Índice: 2412, Nombre de columna: T2_12_h21
# Índice: 2413, Nombre de columna: T2_13_h21
# Índice: 2414, Nombre de columna: T2_14_h21
# Índice: 2415, Nombre de columna: T2_15_h21
# Índice: 2416, Nombre de columna: RAINNC_0_h21
# Índice: 2417, Nombre de columna: RAINNC_1_h21
# Índice: 2418, Nombre de columna: RAINNC_2_h21
# Índice: 2419, Nombre de columna: RAINNC_3_h21
# Índice: 2420, Nombre de columna: RAINNC_4_h21
# Índice: 2421, Nombre de columna: RAINNC_5_h21
# Índice: 2422, Nombre de columna: RAINNC_6_h21
# Índice: 2423, Nombre de columna: RAINNC_7_h21
# Índice: 2424, Nombre de columna: RAINNC_8_h21
# Índice: 2425, Nombre de columna: RAINNC_9_h21
# Índice: 2426, Nombre de columna: RAINNC_10_h21
# Índice: 2427, Nombre de columna: RAINNC_11_h21
# Índice: 2428, Nombre de columna: RAINNC_12_h21
# Índice: 2429, Nombre de columna: RAINNC_13_h21
# Índice: 2430, Nombre de columna: RAINNC_14_h21
# Índice: 2431, Nombre de columna: RAINNC_15_h21
# Índice: 2432, Nombre de columna: SWDOWN_0_h21
# Índice: 2433, Nombre de columna: SWDOWN_1_h21
# Índice: 2434, Nombre de columna: SWDOWN_2_h21
# Índice: 2435, Nombre de columna: SWDOWN_3_h21
# Índice: 2436, Nombre de columna: SWDOWN_4_h21
# Índice: 2437, Nombre de columna: SWDOWN_5_h21
# Índice: 2438, Nombre de columna: SWDOWN_6_h21
# Índice: 2439, Nombre de columna: SWDOWN_7_h21
# Índice: 2440, Nombre de columna: SWDOWN_8_h21
# Índice: 2441, Nombre de columna: SWDOWN_9_h21
# Índice: 2442, Nombre de columna: SWDOWN_10_h21
# Índice: 2443, Nombre de columna: SWDOWN_11_h21
# Índice: 2444, Nombre de columna: SWDOWN_12_h21
# Índice: 2445, Nombre de columna: SWDOWN_13_h21
# Índice: 2446, Nombre de columna: SWDOWN_14_h21
# Índice: 2447, Nombre de columna: SWDOWN_15_h21
# Índice: 2448, Nombre de columna: GLW_0_h21
# Índice: 2449, Nombre de columna: GLW_1_h21
# Índice: 2450, Nombre de columna: GLW_2_h21
# Índice: 2451, Nombre de columna: GLW_3_h21
# Índice: 2452, Nombre de columna: GLW_4_h21
# Índice: 2453, Nombre de columna: GLW_5_h21
# Índice: 2454, Nombre de columna: GLW_6_h21
# Índice: 2455, Nombre de columna: GLW_7_h21
# Índice: 2456, Nombre de columna: GLW_8_h21
# Índice: 2457, Nombre de columna: GLW_9_h21
# Índice: 2458, Nombre de columna: GLW_10_h21
# Índice: 2459, Nombre de columna: GLW_11_h21
# Índice: 2460, Nombre de columna: GLW_12_h21
# Índice: 2461, Nombre de columna: GLW_13_h21
# Índice: 2462, Nombre de columna: GLW_14_h21
# Índice: 2463, Nombre de columna: GLW_15_h21
# Índice: 2464, Nombre de columna: U10_0_h22
# Índice: 2465, Nombre de columna: U10_1_h22
# Índice: 2466, Nombre de columna: U10_2_h22
# Índice: 2467, Nombre de columna: U10_3_h22
# Índice: 2468, Nombre de columna: U10_4_h22
# Índice: 2469, Nombre de columna: U10_5_h22
# Índice: 2470, Nombre de columna: U10_6_h22
# Índice: 2471, Nombre de columna: U10_7_h22
# Índice: 2472, Nombre de columna: U10_8_h22
# Índice: 2473, Nombre de columna: U10_9_h22
# Índice: 2474, Nombre de columna: U10_10_h22
# Índice: 2475, Nombre de columna: U10_11_h22
# Índice: 2476, Nombre de columna: U10_12_h22
# Índice: 2477, Nombre de columna: U10_13_h22
# Índice: 2478, Nombre de columna: U10_14_h22
# Índice: 2479, Nombre de columna: U10_15_h22
# Índice: 2480, Nombre de columna: V10_0_h22
# Índice: 2481, Nombre de columna: V10_1_h22
# Índice: 2482, Nombre de columna: V10_2_h22
# Índice: 2483, Nombre de columna: V10_3_h22
# Índice: 2484, Nombre de columna: V10_4_h22
# Índice: 2485, Nombre de columna: V10_5_h22
# Índice: 2486, Nombre de columna: V10_6_h22
# Índice: 2487, Nombre de columna: V10_7_h22
# Índice: 2488, Nombre de columna: V10_8_h22
# Índice: 2489, Nombre de columna: V10_9_h22
# Índice: 2490, Nombre de columna: V10_10_h22
# Índice: 2491, Nombre de columna: V10_11_h22
# Índice: 2492, Nombre de columna: V10_12_h22
# Índice: 2493, Nombre de columna: V10_13_h22
# Índice: 2494, Nombre de columna: V10_14_h22
# Índice: 2495, Nombre de columna: V10_15_h22
# Índice: 2496, Nombre de columna: RAINC_0_h22
# Índice: 2497, Nombre de columna: RAINC_1_h22
# Índice: 2498, Nombre de columna: RAINC_2_h22
# Índice: 2499, Nombre de columna: RAINC_3_h22
# Índice: 2500, Nombre de columna: RAINC_4_h22
# Índice: 2501, Nombre de columna: RAINC_5_h22
# Índice: 2502, Nombre de columna: RAINC_6_h22
# Índice: 2503, Nombre de columna: RAINC_7_h22
# Índice: 2504, Nombre de columna: RAINC_8_h22
# Índice: 2505, Nombre de columna: RAINC_9_h22
# Índice: 2506, Nombre de columna: RAINC_10_h22
# Índice: 2507, Nombre de columna: RAINC_11_h22
# Índice: 2508, Nombre de columna: RAINC_12_h22
# Índice: 2509, Nombre de columna: RAINC_13_h22
# Índice: 2510, Nombre de columna: RAINC_14_h22
# Índice: 2511, Nombre de columna: RAINC_15_h22
# Índice: 2512, Nombre de columna: T2_0_h22
# Índice: 2513, Nombre de columna: T2_1_h22
# Índice: 2514, Nombre de columna: T2_2_h22
# Índice: 2515, Nombre de columna: T2_3_h22
# Índice: 2516, Nombre de columna: T2_4_h22
# Índice: 2517, Nombre de columna: T2_5_h22
# Índice: 2518, Nombre de columna: T2_6_h22
# Índice: 2519, Nombre de columna: T2_7_h22
# Índice: 2520, Nombre de columna: T2_8_h22
# Índice: 2521, Nombre de columna: T2_9_h22
# Índice: 2522, Nombre de columna: T2_10_h22
# Índice: 2523, Nombre de columna: T2_11_h22
# Índice: 2524, Nombre de columna: T2_12_h22
# Índice: 2525, Nombre de columna: T2_13_h22
# Índice: 2526, Nombre de columna: T2_14_h22
# Índice: 2527, Nombre de columna: T2_15_h22
# Índice: 2528, Nombre de columna: RAINNC_0_h22
# Índice: 2529, Nombre de columna: RAINNC_1_h22
# Índice: 2530, Nombre de columna: RAINNC_2_h22
# Índice: 2531, Nombre de columna: RAINNC_3_h22
# Índice: 2532, Nombre de columna: RAINNC_4_h22
# Índice: 2533, Nombre de columna: RAINNC_5_h22
# Índice: 2534, Nombre de columna: RAINNC_6_h22
# Índice: 2535, Nombre de columna: RAINNC_7_h22
# Índice: 2536, Nombre de columna: RAINNC_8_h22
# Índice: 2537, Nombre de columna: RAINNC_9_h22
# Índice: 2538, Nombre de columna: RAINNC_10_h22
# Índice: 2539, Nombre de columna: RAINNC_11_h22
# Índice: 2540, Nombre de columna: RAINNC_12_h22
# Índice: 2541, Nombre de columna: RAINNC_13_h22
# Índice: 2542, Nombre de columna: RAINNC_14_h22
# Índice: 2543, Nombre de columna: RAINNC_15_h22
# Índice: 2544, Nombre de columna: SWDOWN_0_h22
# Índice: 2545, Nombre de columna: SWDOWN_1_h22
# Índice: 2546, Nombre de columna: SWDOWN_2_h22
# Índice: 2547, Nombre de columna: SWDOWN_3_h22
# Índice: 2548, Nombre de columna: SWDOWN_4_h22
# Índice: 2549, Nombre de columna: SWDOWN_5_h22
# Índice: 2550, Nombre de columna: SWDOWN_6_h22
# Índice: 2551, Nombre de columna: SWDOWN_7_h22
# Índice: 2552, Nombre de columna: SWDOWN_8_h22
# Índice: 2553, Nombre de columna: SWDOWN_9_h22
# Índice: 2554, Nombre de columna: SWDOWN_10_h22
# Índice: 2555, Nombre de columna: SWDOWN_11_h22
# Índice: 2556, Nombre de columna: SWDOWN_12_h22
# Índice: 2557, Nombre de columna: SWDOWN_13_h22
# Índice: 2558, Nombre de columna: SWDOWN_14_h22
# Índice: 2559, Nombre de columna: SWDOWN_15_h22
# Índice: 2560, Nombre de columna: GLW_0_h22
# Índice: 2561, Nombre de columna: GLW_1_h22
# Índice: 2562, Nombre de columna: GLW_2_h22
# Índice: 2563, Nombre de columna: GLW_3_h22
# Índice: 2564, Nombre de columna: GLW_4_h22
# Índice: 2565, Nombre de columna: GLW_5_h22
# Índice: 2566, Nombre de columna: GLW_6_h22
# Índice: 2567, Nombre de columna: GLW_7_h22
# Índice: 2568, Nombre de columna: GLW_8_h22
# Índice: 2569, Nombre de columna: GLW_9_h22
# Índice: 2570, Nombre de columna: GLW_10_h22
# Índice: 2571, Nombre de columna: GLW_11_h22
# Índice: 2572, Nombre de columna: GLW_12_h22
# Índice: 2573, Nombre de columna: GLW_13_h22
# Índice: 2574, Nombre de columna: GLW_14_h22
# Índice: 2575, Nombre de columna: GLW_15_h22
# Índice: 2576, Nombre de columna: U10_0_h23
# Índice: 2577, Nombre de columna: U10_1_h23
# Índice: 2578, Nombre de columna: U10_2_h23
# Índice: 2579, Nombre de columna: U10_3_h23
# Índice: 2580, Nombre de columna: U10_4_h23
# Índice: 2581, Nombre de columna: U10_5_h23
# Índice: 2582, Nombre de columna: U10_6_h23
# Índice: 2583, Nombre de columna: U10_7_h23
# Índice: 2584, Nombre de columna: U10_8_h23
# Índice: 2585, Nombre de columna: U10_9_h23
# Índice: 2586, Nombre de columna: U10_10_h23
# Índice: 2587, Nombre de columna: U10_11_h23
# Índice: 2588, Nombre de columna: U10_12_h23
# Índice: 2589, Nombre de columna: U10_13_h23
# Índice: 2590, Nombre de columna: U10_14_h23
# Índice: 2591, Nombre de columna: U10_15_h23
# Índice: 2592, Nombre de columna: V10_0_h23
# Índice: 2593, Nombre de columna: V10_1_h23
# Índice: 2594, Nombre de columna: V10_2_h23
# Índice: 2595, Nombre de columna: V10_3_h23
# Índice: 2596, Nombre de columna: V10_4_h23
# Índice: 2597, Nombre de columna: V10_5_h23
# Índice: 2598, Nombre de columna: V10_6_h23
# Índice: 2599, Nombre de columna: V10_7_h23
# Índice: 2600, Nombre de columna: V10_8_h23
# Índice: 2601, Nombre de columna: V10_9_h23
# Índice: 2602, Nombre de columna: V10_10_h23
# Índice: 2603, Nombre de columna: V10_11_h23
# Índice: 2604, Nombre de columna: V10_12_h23
# Índice: 2605, Nombre de columna: V10_13_h23
# Índice: 2606, Nombre de columna: V10_14_h23
# Índice: 2607, Nombre de columna: V10_15_h23
# Índice: 2608, Nombre de columna: RAINC_0_h23
# Índice: 2609, Nombre de columna: RAINC_1_h23
# Índice: 2667, Nombre de columna: SWDOWN_11_h23
# Índice: 2668, Nombre de columna: SWDOWN_12_h23
# Índice: 2669, Nombre de columna: SWDOWN_13_h23
# Índice: 2670, Nombre de columna: SWDOWN_14_h23
# Índice: 2671, Nombre de columna: SWDOWN_15_h23
# Índice: 2672, Nombre de columna: GLW_0_h23
# Índice: 2673, Nombre de columna: GLW_1_h23
# Índice: 2674, Nombre de columna: GLW_2_h23
# Índice: 2675, Nombre de columna: GLW_3_h23
# Índice: 2676, Nombre de columna: GLW_4_h23
# Índice: 2677, Nombre de columna: GLW_5_h23
# Índice: 2678, Nombre de columna: GLW_6_h23
# Índice: 2679, Nombre de columna: GLW_7_h23
# Índice: 2680, Nombre de columna: GLW_8_h23
# Índice: 2681, Nombre de columna: GLW_9_h23
# Índice: 2682, Nombre de columna: GLW_10_h23
# Índice: 2683, Nombre de columna: GLW_11_h23
# Índice: 2684, Nombre de columna: GLW_12_h23
# Índice: 2685, Nombre de columna: GLW_13_h23
# Índice: 2686, Nombre de columna: GLW_14_h23
# Índice: 2687, Nombre de columna: GLW_15_h23
# Índice: 2688, Nombre de columna: sin_day
# Índice: 2689, Nombre de columna: cos_day
# Índice: 2690, Nombre de columna: sin_year
# Índice: 2691, Nombre de columna: cos_year
# Índice: 2692, Nombre de columna: sin_week
# Índice: 2693, Nombre de columna: cos_week
# Índice: 2694, Nombre de columna: UIZ
# Índice: 2695, Nombre de columna: AJU
# Índice: 2696, Nombre de columna: ATI
# Índice: 2697, Nombre de columna: CUA
# Índice: 2698, Nombre de columna: SFE
# Índice: 2699, Nombre de columna: SAG
# Índice: 2700, Nombre de columna: CUT
# Índice: 2701, Nombre de columna: PED
# Índice: 2702, Nombre de columna: TAH
# Índice: 2703, Nombre de columna: GAM
# Índice: 2704, Nombre de columna: IZT
# Índice: 2705, Nombre de columna: CCA
# Índice: 2706, Nombre de columna: HGM
# Índice: 2707, Nombre de columna: LPR
# Índice: 2708, Nombre de columna: MGH
# Índice: 2709, Nombre de columna: CAM
# Índice: 2710, Nombre de columna: FAC
# Índice: 2711, Nombre de columna: TLA
# Índice: 2712, Nombre de columna: XAL
# Índice: 2713, Nombre de columna: LLA
# Índice: 2714, Nombre de columna: TLI
# Índice: 2715, Nombre de columna: UAX
# Índice: 2716, Nombre de columna: BJU
# Índice: 2717, Nombre de columna: MPA
# Índice: 2718, Nombre de columna: MON
# Índice: 2719, Nombre de columna: NEZ
# Índice: 2720, Nombre de columna: INN
# Índice: 2721, Nombre de columna: AJM
# Índice: 2722, Nombre de columna: VIF
# Índice: 2723, Nombre de columna: MER_hm0
# Índice: 2724, Nombre de columna: MER_hm1
# Índice: 2725, Nombre de columna: MER_hm2
# Índice: 2726, Nombre de columna: MER_hm3
# Índice: 2727, Nombre de columna: MER_hm4
# Índice: 2728, Nombre de columna: MER_hm5
# Índice: 2729, Nombre de columna: MER_hm6
# Índice: 2730, Nombre de columna: MER_hm7
# Índice: 2731, Nombre de columna: MER_hm8
# Índice: 2732, Nombre de columna: MER_hm9
# Índice: 2733, Nombre de columna: MER_hm10
# Índice: 2734, Nombre de columna: MER_hm11
# Índice: 2735, Nombre de columna: MER_hm12
# Índice: 2736, Nombre de columna: MER_hm13
# Índice: 2737, Nombre de columna: MER_hm14
# Índice: 2738, Nombre de columna: MER_hm15
# Índice: 2739, Nombre de columna: MER_hm16
# Índice: 2740, Nombre de columna: MER_hm17
# Índice: 2741, Nombre de columna: MER_hm18
# Índice: 2742, Nombre de columna: MER_hm19
# Índice: 2743, Nombre de columna: MER_hm20
# Índice: 2744, Nombre de columna: MER_hm21
# Índice: 2745, Nombre de columna: MER_hm22
# Índice: 2746, Nombre de columna: MER_hm23
# Índice: 2747, Nombre de columna: cont_pmco
# Índice: 2748, Nombre de columna: cont_pmdoscinco
# Índice: 2749, Nombre de columna: cont_nox
# Índice: 2750, Nombre de columna: cont_co
# Índice: 2751, Nombre de columna: cont_nodos
# Índice: 2752, Nombre de columna: cont_no
# Índice: 2753, Nombre de columna: cont_sodos
# Índice: 2754, Nombre de columna: cont_pmdiez
# Índice: 2755, Nombre de columna: MER

# %%
data_norm_df
# Out:
#                      U10_0_h0  U10_1_h0  U10_2_h0  U10_3_h0  U10_4_h0  \
# fecha
# 2019-01-01 03:00:00 -1.186342  0.369620  0.678588 -0.871397 -0.039127
# 2019-01-01 04:00:00 -1.132822  0.261992  0.454843 -0.800826 -0.237256
# 2019-01-01 05:00:00 -1.045852  0.426599  0.678588 -0.968431 -0.370777
# 2019-01-01 06:00:00 -0.410303  0.901427  0.698929 -1.047823  0.034095
# 2019-01-01 07:00:00 -0.102563  1.255965  1.583739 -0.262724  0.301138
# ...                       ...       ...       ...       ...       ...
# 2019-12-30 20:00:00  1.309026  0.711496  0.261609 -0.262724 -0.021898
# 2019-12-30 21:00:00  1.088256  0.458254  0.220928 -0.571471 -0.112348
# 2019-12-30 22:00:00  0.867487  0.413937  0.322630 -0.245081 -0.004670
# 2019-12-30 23:00:00  0.820657  0.426599  0.444673  0.134236  0.258066
# 2019-12-31 00:00:00  0.332287 -0.035567 -0.531670 -0.042191  0.546645
#
#                      U10_5_h0  U10_6_h0  U10_7_h0  U10_8_h0  U10_9_h0  ...  \
# fecha                                                                  ...
# 2019-01-01 03:00:00  0.054214  0.096991 -1.008394  0.348566  0.924830  ...
# 2019-01-01 04:00:00 -0.028661 -0.236134 -1.458467  0.519445  0.897285  ...
# 2019-01-01 05:00:00  0.084747 -0.243074 -1.908540  0.237726  1.029503  ...
# 2019-01-01 06:00:00  0.250496 -0.097332 -1.921585  0.334711  1.051540  ...
# 2019-01-01 07:00:00  0.176345 -0.145913 -1.458467  0.136122  0.588775  ...
# ...                       ...       ...       ...       ...       ...  ...
# 2019-12-30 20:00:00 -0.451759 -0.090392  0.765807 -0.570484 -0.375320  ...
# 2019-12-30 21:00:00 -0.229306 -0.451277  0.485327 -0.464262 -0.171483  ...
# 2019-12-30 22:00:00 -0.107174 -0.735821  0.498373 -0.154833 -0.176992  ...
# 2019-12-30 23:00:00 -0.015576 -0.770521  0.093959  0.644140 -0.452447  ...
# 2019-12-31 00:00:00  0.677956  0.950623  0.707102  1.267616  2.213962  ...
#
#                      MER_hm23  cont_pmco  cont_pmdoscinco  cont_nox   cont_co  \
# fecha
# 2019-01-01 03:00:00 -3.907676   0.847050         1.277520  0.384005  0.272976
# 2019-01-01 04:00:00 -3.907676   0.762580         1.105209  0.384005  0.272976
# 2019-01-01 05:00:00 -3.907676   0.828279         1.476340  0.571802  0.275043
# 2019-01-01 06:00:00 -3.907676   1.006606         2.205347  0.513116  0.272976
# 2019-01-01 07:00:00 -3.907676   0.940906         2.152328  0.900447  0.281243
# ...                       ...        ...              ...       ...       ...
# 2019-12-30 20:00:00 -0.103959   0.584253         0.256910  0.067098  0.256237
# 2019-12-30 21:00:00 -0.103959   0.631181         0.217146  0.231420  0.261403
# 2019-12-30 22:00:00 -0.158820   0.621796         0.309929  0.207946  0.260370
# 2019-12-30 23:00:00 -0.177108   0.696881         0.270165  0.137522  0.255203
# 2019-12-31 00:00:00 -0.177108   0.678109         0.336438  0.184471  0.257890
#
#                      cont_nodos   cont_no  cont_sodos  cont_pmdiez       MER
# fecha
# 2019-01-01 03:00:00    0.277615  0.397773    0.149677     1.351970 -0.782759
# 2019-01-01 04:00:00    0.277615  0.397773    0.149677     1.079696 -0.782759
# 2019-01-01 05:00:00    0.324777  0.590403    0.180312     1.505865 -0.745920
# 2019-01-01 06:00:00    0.277615  0.562884    0.180312     2.370040 -0.745920
# 2019-01-01 07:00:00    0.246173  1.030698    0.149677     2.239822 -0.782759
# ...                         ...       ...         ...          ...       ...
# 2019-12-30 20:00:00    0.230453  0.081311    0.027137     0.144492 -0.635404
# 2019-12-30 21:00:00    0.324777  0.191385    0.027137     0.097140 -0.745920
# 2019-12-30 22:00:00    0.324777  0.177625    0.027137     0.286549 -0.745920
# 2019-12-30 23:00:00    0.277615  0.108829    0.027137     0.215520 -0.709081
# 2019-12-31 00:00:00    0.230453  0.218903    0.027137     0.227359 -0.745920
#
# [8069 rows x 2756 columns]

# %%
import pandas as pd

# Asumiendo que tu DataFrame se llama 'data'

# Lista de variables a considerar
variables = ['U10', 'V10', 'RAINC','RAINNC', 'GLW', 'SWDOWN']

# Encuentra las columnas que contienen 'h0' para cada variable y calcula el promedio
for var in variables:
    columnas_h23 = [col for col in data.columns if f'{var}_' in col and '_h23' in col]
    promedio_h23 = data[columnas_h23].mean(axis=1)
    data[f'{var}_prom_h23'] = promedio_h23

# Muestra el DataFrame actualizado con las nuevas columnas de promedios
print(data)
# Out:
#                      U10_0_h0  U10_1_h0  U10_2_h0  U10_3_h0  U10_4_h0  \
# fecha
# 2019-01-01 03:00:00     -1.98      1.02      1.01     -0.91      0.49
# 2019-01-01 04:00:00     -1.90      0.85      0.79     -0.83      0.03
# 2019-01-01 05:00:00     -1.77      1.11      1.01     -1.02     -0.28
# 2019-01-01 06:00:00     -0.82      1.86      1.03     -1.11      0.66
# 2019-01-01 07:00:00     -0.36      2.42      1.90     -0.22      1.28
# 2019-01-01 04:00:00    266.429375         0.000000
# 2019-01-01 05:00:00    271.175625         0.000000
# 2019-01-01 06:00:00    272.523750         0.000000
# 2019-01-01 07:00:00    275.267500         0.000000
# ...                           ...              ...
# 2019-12-30 20:00:00    279.073125       843.281250
# 2019-12-30 21:00:00    282.424375       797.385625
# 2019-12-30 22:00:00    285.579375       677.524375
# 2019-12-30 23:00:00    288.258125       494.879375
# 2019-12-31 00:00:00    283.254375       269.263125
#
# [8069 rows x 2762 columns]

# %%
# Loading the best weight file 
import glob
path_model_weights = join(f'{output_folder}',f'models')
print(path_model_weights)
model_weights_file = join(path_model_weights,f'{model_name}*')
weight_files = glob.glob(model_weights_file)
lista_weights =[]
for item in weight_files:
    lista_weights.append(float(item.split('/')[-1].split('-')[-1].split('.hdf5')[0]))
print(lista_weights)
model_weights_file = glob.glob(join(path_model_weights,f'{model_name}*{min(lista_weights)}*'))
model_weights_file = model_weights_file[0]
print(f'\nModel weight file to use of    {min(lista_weights)}: \n\n',model_weights_file)
# Out:
# /ZION/AirPollutionData/Data/Training/pmt-TE-2010-2018-v2019_r0v3_cr35/cont_otres_MER/models
# [3.49887133, 2.93127537, 2.67732239, 2.28687358, 1.68283856, 1.37983465, 1.209203, 1.16113794, 1.12350702, 1.10939336, 1.04946291, 1.04102898, 0.99829984, 0.98733878, 0.97902191, 0.96025455, 0.92172432, 0.89613497, 0.89016855, 0.88911021, 0.88288945, 0.84593838, 0.82535851, 0.80014533, 0.77187526, 0.76151186, 0.73403257, 0.71335381, 0.6853953, 0.67577046, 0.66156167, 0.6557076, 0.62190419, 0.61988628, 0.61190736, 0.58368236, 0.51771134, 0.50657916, 0.44859606, 0.4384276, 0.42556801, 0.40624207, 0.403478, 0.35795245, 0.33523151, 0.32473207, 0.32112026, 0.30719864, 0.2824167, 0.26343814, 0.25880411, 0.23301615, 0.19328806, 0.16883557, 0.16833481, 0.14989816, 0.14408767, 0.14068298, 0.11810904, 0.10560199, 0.09624197, 0.08418311, 0.07069694, 0.06311236, 0.05816834, 0.05769487, 0.05154153, 0.04067298, 0.03950559, 0.03733109, 0.03634108, 0.03426353, 0.03207029, 0.03181097, 0.0304714, 0.02712835, 0.02668917, 0.02610355, 0.0237946]
#
# Model weight file to use of    0.0237946:
#
#  /ZION/AirPollutionData/Data/Training/pmt-TE-2010-2018-v2019_r0v3_cr35/cont_otres_MER/models/2023_MER_0_97_t_t_cont_otres_MER_2023_05_04_18_28-epoch-840-loss-0.02379460.hdf5

# %%
import sys
sys.path.append('./eoas_pyutils')

from datetime import date, datetime, timedelta

from viz_utils.eoa_viz import EOAImageVisualizer
from sklearn import preprocessing
from conf.localConstants import constants
from pandas import DataFrame
import pandas as pd
import time
from ai_common.constants.AI_params import *
from os.path import join
from conf.params import LocalTrainingParams

from conf.TrainingUserConfiguration import get_makeprediction_config
from io_utils.io_common import  create_folder
from AI.data_generation.utilsDataFormat import *
from ai_common.models.modelSelector import select_1d_model
from os import listdir
import glob
import os

# *********** Chooses the proper model ***********
#print('Reading model ....')
#model = select_1d_model(config)

# *********** Reads the weights***********
print('Reading weights ....')
model.load_weights(model_weights_file)

#create_folder(output_folder)
#create_folder(output_imgs_folder)
from conf.TrainingUserConfiguration import get_makeprediction_config
config = get_makeprediction_config()
# Out:
# Reading weights ....

# %%
print(config)
# *********** Makes a dataframe to contain the DSC information **********
metrics_dict = config[ClassificationParams.metrics]
# Out:
# {<ClassificationParams.input_file: 19>: '/ZION/AirPollutionData/Data/MergedDataCSV/16/2015_cont_otres_AllStations.csv', <ClassificationParams.output_folder: 2>: '/ZION/AirPollutionData/Data/Results', <ClassificationParams.model_weights_file: 8>: '/ZION/AirPollutionData/Training/models', <ClassificationParams.split_file: 30>: '', <ClassificationParams.output_file_name: 4>: '/ZION/AirPollutionData/Training/Results/2023.csv', <ClassificationParams.output_imgs_folder: 3>: '/ZION/AirPollutionData/Data/Results/2023', <ClassificationParams.generate_images: 22>: False, <ClassificationParams.show_imgs: 5>: False, <ClassificationParams.save_prediction: 21>: True, <LocalTrainingParams.stations: 2>: ['UIZ', 'AJU', 'ATI', 'CUA', 'SFE', 'SAG', 'CUT', 'PED', 'TAH', 'GAM', 'IZT', 'CCA', 'HGM', 'LPR', 'MGH', 'CAM', 'FAC', 'TLA', 'MER', 'XAL', 'LLA', 'TLI', 'UAX', 'BJU', 'MPA', 'MON', 'NEZ', 'INN', 'AJM', 'VIF'], <LocalTrainingParams.pollutants: 1>: ['otres'], <LocalTrainingParams.forecasted_hours: 7>: 24, <ClassificationParams.metrics: 10>: {'rmse': <function mean_squared_error at 0x7f521fd82b90>, 'mae': <function mean_absolute_error at 0x7f521fd829e0>, 'r2': <function r2_score at 0x7f521fd82e60>, 'ex_var': <function explained_variance_score at 0x7f521fd82dd0>}, <TrainingParams.config_name: 14>: '2023', <LocalTrainingParams.filter_dates: 12>: False, <ModelParams.MODEL: 4>: <AiModels.ML_PERCEPTRON: 10>, <ModelParams.DROPOUT: 1>: True, <ModelParams.BATCH_NORMALIZATION: 2>: True, <ModelParams.CELLS_PER_HIDDEN_LAYER: 14>: [300, 300, 200, 100, 100, 100, 100, 100, 100], <ModelParams.NUMBER_OF_OUTPUT_CLASSES: 12>: 1, <ModelParams.ACTIVATION_HIDDEN_LAYERS: 15>: 'relu', <ModelParams.ACTIVATION_OUTPUT_LAYERS: 16>: None, <ModelParams.HIDDEN_LAYERS: 13>: 9}

# %%
# *********** Iterates over each case *********
t0 = time.time()
# -------------------- Reading data -------------
output_nn_all = model.predict(X, verbose=1)

# Plotting some intermediate results
import matplotlib.pyplot as plt
size = 24 * 10  # Two months of data
start = np.random.randint(0, len(data) - size)
end = start + size
#plt.figure(figsize=[64, 8])
plt.figure(figsize=[20, 10])
x_plot = range(len(Y))
y_plot = Y
u_plot = X
yy_plot = Y_df.iloc[start:end].values
plot_this_many= 24*20
plt.plot(x_plot[0:plot_this_many], y_plot[0:plot_this_many], label='Original')
plt.plot(x_plot[0:plot_this_many], output_nn_all[0:plot_this_many,0], label='Forecasted')
plt.legend()
plt.show()

print(F'\t Done! Elapsed time {time.time() - t0:0.2f} seg')
# Out:
# 239/239 [==============================] - 1s 3ms/step
# 	 Done! Elapsed time 1.33 seg

# %%
X2_df = data.loc[datetimes_str[accepted_times_idx]]
Y2_df = data.loc[datetimes_str[y_times_idx]][cur_station]
X2 = X2_df.values
Y2 = Y2_df.values

# %%
# Asumiendo que tu array se llama X:
U10_0_h0_column = X2[:, -6]
V10_0_h0_column = X2[:, -5]
RAIN_0_h0_column = X2[:, -4]/10
RAINNC_0_h0_column = X2[:, -3]/10
SWDOWN_0_h0_column = X2[:, -1]/800
GLW_0_h0_column = X2[:, -2]/200
# Estaciones contaminantes
# Asumiendo que tu array se llama X
idx_sta0 = 2694

# Crear una lista vacía para almacenar las columnas de las estaciones
o3_columns = []
num_stations = 12
# Obtener las columnas para las estaciones 0 a 11
for i in range(num_stations):
    idx = idx_sta0 + i
    o3_column = X[:, idx]
    o3_columns.append(o3_column)

# Ahora, o3_columns contiene las columnas para las estaciones 0 a 11
# o3_columns[0] corresponde a o3_sta0_column, o3_columns[1] corresponde a o3_sta1_column, etc.


print(U10_0_h0_column)
# Out:
# [-0.9525   -0.411875  0.029375 ...  0.295625  0.531875  0.600625]

# %%
# Calculate the absolute value of the wind
wind_abs = np.sqrt(np.array(U10_0_h0_column)**2 + np.array(V10_0_h0_column)**2)

# *********** Iterates over each case *********
t0 = time.time()
# -------------------- Reading data -------------
output_nn_all = model.predict(X, verbose=1)

# Plotting some intermediate results
import matplotlib.pyplot as plt
size = 24 * 10  # Two months of data
start = np.random.randint(0, len(data) - size)
end = start + size
#plt.figure(figsize=[64, 8])
plt.figure(figsize=[20, 10])
x_plot = range(len(Y))
y_plot = Y
yy_plot = Y_df.iloc[start:end].values
plot_this_many= 24*20
plt.plot(x_plot[0:plot_this_many], y_plot[0:plot_this_many], label='Original')
plt.plot(x_plot[0:plot_this_many], output_nn_all[0:plot_this_many,0], label='Forecasted')

factor_wind = 1.0
#plt.plot(x_plot[0:plot_this_many], factor_wind*U10_0_h0_column[0:plot_this_many], linestyle='--', label='U10_0_h0_column')
#plt.plot(x_plot[0:plot_this_many], factor_wind*V10_0_h0_column[0:plot_this_many], linestyle='--',label='V10_0_h0_column')
plt.plot(x_plot[0:plot_this_many], factor_wind * wind_abs[0:plot_this_many], linestyle='--', label='Wind Abs')

factor_rain = 20
plt.plot(x_plot[0:plot_this_many], factor_rain*RAIN_0_h0_column[0:plot_this_many], linestyle='-',label='RAIN_0_h0_column')
plt.plot(x_plot[0:plot_this_many], factor_rain*RAINNC_0_h0_column[0:plot_this_many], linestyle='-',label='RAINNC_0_h0_column')
factor_swdown = 1
plt.plot(x_plot[0:plot_this_many], factor_swdown*SWDOWN_0_h0_column[0:plot_this_many], linestyle=':',label='SWDOWN_0_h0_column')
factor_glw = 1
plt.plot(x_plot[0:plot_this_many], factor_glw*GLW_0_h0_column[0:plot_this_many], linestyle=':',label='GLW_0_h0_column')

#factor_stations = 1
# Asumiendo que 'o3_columns' contiene las columnas de las estaciones
#for i, o3_column in enumerate(o3_columns):
#    plt.plot(x_plot[:plot_this_many], factor_stations * o3_column[:plot_this_many], linestyle='-', label=f'o3_sta{i}_column')

#plt.plot(x_plot[0:plot_this_many], factor_stations*o3_sta0_column[0:plot_this_many], linestyle='-',label='o3_sta0_column')
#plt.plot(x_plot[0:plot_this_many], factor_stations*o3_sta1_columbbvn[0:plot_this_many], linestyle='-',label='o3_sta1_column')
#plt.plot(x_plot[0:plot_this_many], factor_stations*o3_sta2_column[0:plot_this_many], linestyle='-',label='o3_sta2_column')

plt.legend()
plt.show()

print(F'\t Done! Elapsed time {time.time() - t0:0.2f} seg')
# Out:
# 239/239 [==============================] - 1s 3ms/step
# 	 Done! Elapsed time 1.24 seg

# %%
# Out:
# 0.01482889300199626

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Convertir las fechas en formato de texto a objetos datetime
dates = pd.to_datetime(data.index[::])

# *********** Iterates over each case *********
t0 = time.time()
# -------------------- Reading data -------------
output_nn_all = model.predict(X, verbose=1)

# Plotting some intermediate results
size = 24 * 10  # Two months of data
start = 4141+ (14*24) #np.random.randint(0, len(data) - size)
end = start + size
plt.figure(figsize=[20, 10])

# Limitar el rango de datos a graficar
plot_this_many = 24 * 10
plot_range = slice(start, start + plot_this_many)

# Graficar los datos utilizando las fechas como índice en el eje x
plt.plot(dates[plot_range], Y[plot_range], linewidth=3.0, label='Observed')
plt.plot(dates[plot_range], output_nn_all[plot_range, 0], linewidth=3.0, label='Forecasted')

factor_wind = 0.9
#plt.plot(dates[plot_range], factor_wind*U10_0_h0_column[plot_range], linestyle='--', label='U10_0_h0_column')
#plt.plot(dates[plot_range], factor_wind*V10_0_h0_column[plot_range], linestyle='--', label='V10_0_h0_column')
#plt.plot(x_plot[0:plot_this_many], factor_wind * wind_abs[0:plot_this_many], linestyle='--', label='Wind Abs')
plt.plot(dates[plot_range], factor_wind*wind_abs[plot_range], linestyle='--', label='Wind Abs')

factor_rain = 10
plt.plot(dates[plot_range], factor_rain*RAIN_0_h0_column[plot_range], linestyle='-', label='RAIN_0_h0_column')
plt.plot(dates[plot_range], factor_rain*RAINNC_0_h0_column[plot_range], linestyle='-', label='RAINNC_0_h0_column')

factor_swdown = 1
plt.plot(dates[plot_range], factor_swdown*SWDOWN_0_h0_column[plot_range], linestyle=':', label='SWDOWN_0_h0_column')

factor_glw = 1
plt.plot(dates[plot_range], factor_glw*GLW_0_h0_column[plot_range], linestyle=':', label='GLW_0_h0_column')

plt.legend()

# Personalizar el gráfico
plt.xlabel('Fecha')
plt.ylabel('Valores normalizados')
plt.title(f'Series de tiempo estación {cur_station}')

# Personalizar las fechas en el eje x
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.DayLocator(interval=2))  # Intervalo de días entre las marcas principales
ax.xaxis.set_minor_locator(mdates.DayLocator())  # Marcas menores para cada día
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))  # Formato de las marcas principales
plt.gcf().autofmt_xdate()

# Mostrar el gráfico
plt.show()

print(F'\t Done! Elapsed time {time.time() - t0:0.2f} seg')
# Out:
# 239/239 [==============================] - 1s 3ms/step
# 	 Done! Elapsed time 1.38 seg

# %%
start
# Out:
# 4141

# %% [markdown]
# ### Desnormalización:

# %%
# Obtener la media y la desviación estándar estimada para cada característica
mean = scaler.mean_
std = scaler.scale_

# Imprimir la descripción
print("Media de cada característica:")
print(mean[-1])
print("Desviación estándar estimada de cada característica:")
print(std[-1])
# Out:
# Media de cada característica:
# 24.248367633688733
# Desviación estándar estimada de cada característica:
# 27.1454949356639

# %%
# Desnormalización:
t0 = time.time()
# -------------------- Reading data -------------
output_nn_all = model.predict(X, verbose=1)
yy_plot = output_nn_all
yy_plot = (yy_plot * std[-1]) + mean[-1]

# Plotting some intermediate results
import matplotlib.pyplot as plt
size = 24 * 10  # Two months of data
start = np.random.randint(0, len(data) - size)
end = start + size
#plt.figure(figsize=[64, 8])
plt.figure(figsize=[20, 10])
x_plot = range(len(Y))
y_plot = (Y * std[-1]) + mean[-1]

# Crear una lista vacía para almacenar las columnas desnormalizadas
o3_columns_denorm = []

# Desnormalizar las columnas de las estaciones 0 a 11
for i, o3_column in enumerate(o3_columns):
    idx = idx_sta0 + i
    o3_column_denorm = (o3_column * std[idx] + mean[idx])
    o3_columns_denorm.append(o3_column_denorm)

dife = yy_plot.squeeze() - y_plot
plot_this_many= 24*10

# Asumiendo que 'o3_columns_denorm' contiene las columnas desnormalizadas de las estaciones
for i, o3_column_denorm in enumerate(o3_columns_denorm):
    plt.plot(x_plot[23:plot_this_many+23], o3_column_denorm[:plot_this_many], linestyle='--', label=f'o3_sta{i}')


plt.plot(x_plot[0:plot_this_many], y_plot[0:plot_this_many], linewidth=5.0,label='Original',alpha=0.4)
plt.plot(x_plot[0:plot_this_many], yy_plot[0:plot_this_many,0], linewidth=5.0, label='Forecasted',alpha=0.4)
plt.plot(x_plot[0:plot_this_many], dife[0:plot_this_many], label='diferencia')


#plt.plot(x_plot[start:start + plot_this_many], y_plot[start:start + plot_this_many], label='Original')
#plt.plot(x_plot[start:start + plot_this_many], yy_plot[start:start + plot_this_many,0], label='Forecasted')

# Restringir el eje Y a [-10, 150]
plt.ylim(-10, 150)

plt.legend()
plt.show()

print(F'''\t Done! Elapsed time {time.time() - t0:0.2f} seg
Gráfica de {num_stations} estaciones contaminantes + 23h''')
# Out:
# 239/239 [==============================] - 1s 3ms/step
# 	 Done! Elapsed time 1.31 seg
# Gráfica de 12 estaciones contaminantes + 23h

# %% [markdown]
# #### Gráficas para reporte

# %%
# Desnormalización:
t0 = time.time()
# -------------------- Reading data -------------
output_nn_all = model.predict(X, verbose=1)
yy_plot = output_nn_all
yy_plot = (yy_plot * std[-1]) + mean[-1]

# Plotting some intermediate results
import matplotlib.pyplot as plt
size = 24 * 10  # Two months of data
start = 0 #np.random.randint(0, len(data) - size)
end = start + size
#plt.figure(figsize=[64, 8])
plt.figure(figsize=[10, 5])
x_plot = range(len(Y))
y_plot = (Y * std[-1]) + mean[-1]

dife = yy_plot.squeeze() - y_plot

plot_this_many= 24*20

#plt.plot(x_plot[0:plot_this_many], y_plot[0:plot_this_many], label='Original')
#plt.plot(x_plot[0:plot_this_many], yy_plot[0:plot_this_many,0], label='Forecasted')
#plt.plot(x_plot[0:plot_this_many], dife[0:plot_this_many], label='diferencia')
plt.xlabel('Tiempo pronosticado [horas]')
plt.ylabel(r'Nivel contaminante $O_3$ [ppm]')
plt.plot(x_plot[start:start + plot_this_many], y_plot[start:start + plot_this_many], label='Original')
plt.plot(x_plot[start:start + plot_this_many], yy_plot[start:start + plot_this_many,0], label='Pronóstico')
plt.title(f'Niveles pronóstico estación {cur_station} {test_year}')
plt.legend()
plt.show()

print(F'\t Done! Elapsed time {time.time() - t0:0.2f} seg')
# Out:
# 239/239 [==============================] - 1s 3ms/step
# 	 Done! Elapsed time 1.26 seg

# %% [markdown]
# ### Métricas:
# #### Índice de correlación, MAE, MAPE, MSE, RMSE, R2
# Índice de correlación: \rho_xy = Cov_xy / \sigma_x \sigma_y

# %%
print(f"Métricas estación {cur_station} para el año {test_year}\n")
data = {"x": y_plot, "y": yy_plot.squeeze()}
df = pd.DataFrame(data)
df.dropna(inplace=True)
corr_coef = df["x"].corr(df["y"])
print(f"Índice de correlación:                     {corr_coef:.4f}")
sb.glue("corr_coef", corr_coef)

y_true, y_prediction = y_plot, yy_plot.squeeze()

import numpy as np

# Supongamos que y_true e y_prediction son tus vectores de etiquetas verdaderas y predicciones, respectivamente
mask = ~np.isnan(y_true) & ~np.isnan(y_prediction)
y_true = y_true[mask]
y_prediction = y_prediction[mask]


from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_true, y_prediction)
print(f"Error medio absoluto (MAE):                {mae:.4f}")
sb.glue("mae", mae)
from sklearn.metrics import mean_absolute_percentage_error

mape = mean_absolute_percentage_error(y_true, y_prediction)
print(f"Porcentaje de error medio absoluto (MAPE): {mape:.2f}%")
sb.glue("mape", mape)
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_true, y_prediction)
print(f"Error cuadrático promedio (MSE):           {mse:.4f}")
sb.glue("mse", mse)

import numpy as np

rmse = np.sqrt(mean_squared_error(y_true, y_prediction))
print(f"Raíz del error cuadrático promedio (RMSE): {rmse:.4f} ppm")
sb.glue("rmse", rmse)

from sklearn.metrics import r2_score

r2 = r2_score(y_true, y_prediction)
print(f"Coeficiente de determinación (R2):         {r2:.4f}")
sb.glue("r2", r2)


# Datos grafico
observed, predicted = y_true, y_prediction

# Calcular la pendiente y la intercepción de la línea de ajuste
slope, intercept = np.polyfit(observed, predicted, 1)

# Crear el scatter plot
size = 7
fig, ax = plt.subplots(figsize=(size, size))

ax.scatter(observed, predicted, s=5, marker='+')

# Añadir la línea de ajuste al gráfico
#ax.plot(observed, slope*observed + intercept, color='red')
ax.plot(observed, slope*observed + intercept, color='red', linewidth=4, alpha=0.7, label='Ajuste lineal')
#ax.plot(observed, observed , color='blue', linewidth=4, alpha=0.7, label='Ideal')


# Imprimir la pendiente y la intercepción de la línea de ajuste
#print("Pendiente:", slope)
#print("Intercepción:", intercept)

# Añadir la ecuación de la recta al gráfico
eqn = f"""Estación: {cur_station} {test_year}
Pronosticado = {slope:.2f}*Observado + {intercept:.2f}
RMSE: {rmse:.2f} ppm
N: {len(y_true)}"""
sb.glue("slope", slope)
sb.glue("intercept", intercept)
ax.text(0.1, 0.8, eqn, transform=ax.transAxes, fontsize=12)

# Establecer los ejes X e Y con el mismo rango de unidades
max_val = 200 #max(np.max(observed), np.max(predicted))
ax.set_xlim([0, max_val])
ax.set_ylim([0, max_val])

# Etiquetas de los ejes y título del gráfico
ax.set_xlabel(r'Nivel contaminante $O_3$ observado [ppm]')
#plt.ylabel(r'Nivel contaminante $O_3$ [ppm]')
ax.set_ylabel(r'Nivel contaminante $O_3$ pronosticado [ppm]')
#ax.set_ylabel('Valores Pronosticados')

#ax.set_title(f'Scatter Plot de Correlación con Ajuste Lineal estacion {cur_station}')
print('\n')
#print(f'''Scatter Plot de estacion {cur_station} {test_year}''')

# Agregar la leyenda
#ax.legend()

# Mostrar el gráfico
plt.show()
# Out:
# Métricas estación MER para el año 2019
#
# Índice de correlación:                     0.8649
# Error medio absoluto (MAE):                10.1653
# Porcentaje de error medio absoluto (MAPE): 0.64%
# Error cuadrático promedio (MSE):           216.8631
# Raíz del error cuadrático promedio (RMSE): 14.7263 ppm
# Coeficiente de determinación (R2):         0.7347

# %%
print(f"Métricas estación {cur_station} para el año {test_year}\n")
data = {"x": y_plot, "y": yy_plot.squeeze()}
df = pd.DataFrame(data)
df.dropna(inplace=True)
corr_coef = df["x"].corr(df["y"])
print(f"Índice de correlación:                     {corr_coef:.4f}")

y_true, y_prediction = y_plot, yy_plot.squeeze()

import numpy as np

# Supongamos que y_true e y_prediction son tus vectores de etiquetas verdaderas y predicciones, respectivamente
mask = ~np.isnan(y_true) & ~np.isnan(y_prediction)
y_true = y_true[mask]
y_prediction = y_prediction[mask]


from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_true, y_prediction)
print(f"Error medio absoluto (MAE):                {mae:.4f}")

from sklearn.metrics import mean_absolute_percentage_error

mape = mean_absolute_percentage_error(y_true, y_prediction)
print(f"Porcentaje de error medio absoluto (MAPE): {mape:.2f}%")

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_true, y_prediction)
print(f"Error cuadrático promedio (MSE):           {mse:.4f}")

import numpy as np

rmse = np.sqrt(mean_squared_error(y_true, y_prediction))
print(f"Raíz del error cuadrático promedio (RMSE): {rmse:.4f} ppm")

from sklearn.metrics import r2_score

r2 = r2_score(y_true, y_prediction)
print(f"Coeficiente de determinación (R2):         {r2:.4f}")

# Datos grafico
observed, predicted = y_true, y_prediction

# Calcular la pendiente y la intercepción de la línea de ajuste
slope, intercept = np.polyfit(observed, predicted, 1)

# Crear el scatter plot
size = 7
fig, ax = plt.subplots(figsize=(size, size))

ax.scatter(observed, predicted, s=5, marker='+')

# Añadir la línea de ajuste al gráfico
#ax.plot(observed, slope*observed + intercept, color='red')
ax.plot(observed, slope*observed + intercept, color='red', linewidth=4, alpha=0.7, label='Ajuste lineal')
ax.plot(observed, observed , color='blue', linewidth=4, alpha=0.7, label='Ideal')


# Imprimir la pendiente y la intercepción de la línea de ajuste
#print("Pendiente:", slope)
#print("Intercepción:", intercept)

# Añadir la ecuación de la recta al gráfico
eqn = f"""Estación: {cur_station} {test_year}
Pronosticado = {slope:.2f}*Observado + {intercept:.2f}
RMSE: {rmse:.2f} ppm
N: {len(y_true)}"""
ax.text(0.1, 0.8, eqn, transform=ax.transAxes, fontsize=12)

# Establecer los ejes X e Y con el mismo rango de unidades
max_val = 200 #max(np.max(observed), np.max(predicted))
ax.set_xlim([0, max_val])
ax.set_ylim([0, max_val])

# Etiquetas de los ejes y título del gráfico
ax.set_xlabel(r'Nivel contaminante $O_3$ observado [ppm]')
#plt.ylabel(r'Nivel contaminante $O_3$ [ppm]')
ax.set_ylabel(r'Nivel contaminante $O_3$ pronosticado [ppm]')
#ax.set_ylabel('Valores Pronosticados')

#ax.set_title(f'Scatter Plot de Correlación con Ajuste Lineal estacion {cur_station}')
print('\n')
#print(f'''Scatter Plot de estacion {cur_station} {test_year}''')

# Agregar la leyenda
ax.legend()

# Mostrar el gráfico
plt.show()
# Out:
# Métricas estación MER para el año 2019
#
# Índice de correlación:                     0.8649
# Error medio absoluto (MAE):                10.1653
# Porcentaje de error medio absoluto (MAPE): 0.64%
# Error cuadrático promedio (MSE):           216.8631
# Raíz del error cuadrático promedio (RMSE): 14.7263 ppm
# Coeficiente de determinación (R2):         0.7347

# %% [markdown]
# ## Metricas comparando valores promedio c/24 hrs y valores máximos c/24 hrs

# %%
import numpy as np

# Aquí asumimos que la longitud actual de y_true es 7020
longitud_actual = y_true.shape[0]
longitud_deseada = (longitud_actual // 24 + 1) * 24  # redondear hacia arriba para que sea divisible por 24

# Agregar ceros al final de y_true, se puede probar agregar nans, pero creo no funcionaría, quizá valores medios?
y_true = np.pad(y_true, (0, longitud_deseada - longitud_actual), mode='constant', constant_values=0)

longitud_actual = y_prediction.shape[0]

# Agregar ceros al final de y_true
y_prediction = np.pad(y_prediction, (0, longitud_deseada - longitud_actual), mode='constant', constant_values=0)

# Supongamos que y_true e y_prediction son numpy arrays de la misma longitud
# y que representan los valores observados y predichos respectivamente

# Obtener el valor máximo de cada día en y_true e y_prediction
max_y_true = np.max(np.reshape(y_true, (-1, 24)), axis=1)
max_y_pred = np.max(np.reshape(y_prediction, (-1, 24)), axis=1)

# Obtener el promedio de los valores de cada día en y_true e y_prediction
mean_y_true = np.mean(np.reshape(y_true, (-1, 24)), axis=1)
mean_y_pred = np.mean(np.reshape(y_prediction, (-1, 24)), axis=1)

# %% [markdown]
# ### Error comparando valores maximos de cada 24 hrs (h24_max_err_mean)

# %%
plt.figure(figsize=[10, 5])

plt.plot(max_y_true - max_y_pred)
h24_max_err_mean = np.mean(max_y_true - max_y_pred)
h24_max_err_std  = np.std(max_y_true - max_y_pred)
sb.glue("h24_max_err_mean", h24_max_err_mean)
sb.glue("h24_max_err_std", h24_max_err_std)

print(f'Error promedio  al comparar valores máximos cada 24 hrs: {h24_max_err_mean}')
print(f'Desviación estándard de diferencia en valores máximos diarios: {h24_max_err_std}')

plt.title(f'Diferencia en valores máximos c/24 hrs Estación:{cur_station} Test: {test_year}')
plt.xlabel('Tiempo pronosticado [día]')
plt.ylabel(r'Diferencia en niveles de $O_3$ [ppm]')
plt.show()
# Out:
# Error promedio  al comparar valores máximos cada 24 hrs: -0.5091412583114957
# Desviación estándard de diferencia en valores máximos diarios: 20.842555573639814

# %% [markdown]
# ### Error comparando valores medios de cada 24 hrs (h24_avg_err_mean)

# %%
plt.figure(figsize=[10, 5])

plt.plot(mean_y_true - mean_y_pred)

h24_avg_err_mean = np.mean(mean_y_true - mean_y_pred)
h24_avg_err_std  = np.std(mean_y_true - mean_y_pred)
sb.glue("h24_avg_err_mean", h24_avg_err_mean)
sb.glue("h24_avg_err_std", h24_avg_err_std)


print(f'Error promedio al comparar valores promedio diarios {h24_avg_err_mean}')
print(f'Desviación estándard de diferencia en valores promedios diarios {h24_avg_err_std}')
plt.title(f'Diferencia en valores promedios de c/24 hrs Estación:{cur_station} Test: {test_year}')
plt.xlabel('Tiempo pronosticado [día]')
plt.ylabel(r'Diferencia en niveles de $O_3$ [ppm]')

plt.show()
# Out:
# Error promedio al comparar valores promedio diarios 1.2423908787710416
# Desviación estándard de diferencia en valores promedios diarios 7.005704174658804

# %%
max_y_true
# Out:
# array([ 76.,  73.,  95., 112.,  86.,  76.,  76.,  76.,  79., 102.,  81.,
#         69.,  51.,  93.,  86.,  80.,  76.,  67.,  77.,  75.,  84.,  50.,
#         64.,  65.,  67.,  77.,  93.,  65.,  57.,  86., 114., 120., 100.,
#        113., 117.,  45.,  86.,  83., 101.,  64.,  82.,  91., 111., 107.,
#         74.,  55.,  51.,  40.,  52.,  74.,  90.,  60.,  84.,  91., 103.,
#        123.,  96.,  96.,  90.,  88., 120., 107., 111.,  70., 118., 113.,
#        103.,  70., 104.,  70.,  76.,  98.,  74.,  89., 109., 105.,  59.,
#         58.,  75.,  90., 137., 113.,  86.,  81., 125.,  80.,  95.,  81.,
#        114.,  78., 155., 107.,  85.,  90., 142., 139., 138., 144., 114.,
#        114., 103., 117., 112.,  72., 109., 121., 116., 132.,  75.,  98.,
#         81., 103.,  94.,  94.,  79.,  67.,  61.,  99., 120., 115., 128.,
#        122., 135., 104.,  93.,  90., 114., 123., 112., 111., 110.,  97.,
#        115., 108., 128., 111.,  71.,  53.,  37.,  36.,  54.,  69., 122.,
#         96.,  81.,  81.,  51.,  80.,  55.,  80., 107., 115.,  93., 102.,
#        110.,  94.,  77.,  63.,  52.,  65.,  81.,  89.,  96.,  78.,  76.,
#         53.,  76.,  51.,  80.,  79., 104.,  63.,  81.,  70.,  81.,  50.,
#         80.,  81.,  80.,  77.,  74.,  75., 132.,  96.,  83.,  85.,  80.,
#         73.,  87.,  90.,  93.,  69.,  80.,  68.,  93.,  84.,  97.,  97.,
#         37.,  82.,  82., 104., 111.,  79.,  90.,  96.,  75.,  93.,  91.,
